# %% [markdown]
# # ETL through Spotify public API

# %% [markdown]
# # Assignment 1
#
# This notebook contains a set of exercises that will guide you through the different steps of this assignment. Solutions need to be code-based, i.e. hard-coded or manually computed results will not be accepted. Remember to write your solutions to each exercise in the dedicated cells and to not modify the test cells. When you are done completing all the exercises submit this same notebook back to moodle in .ipynb format.
#
# <div class="alert alert-success">The aim of this assignment is to create and save a dataset containing information about every song in a given playlist by requesting data from Spotify's API. You will then use this dataset during the Artifical Intelligence I course to train a predictive model.</div>
#
# <div class="alert alert-danger"><b>Submission deadline:</b> Sunday, October 3rd, 23:55</div>

# %% [markdown]
# ***Collaborated with Carla Sureda, Lee Yen Tang Cheng, Matilda Minarelli***

# %% [markdown]
# ## Getting client credentials
#
# Spotify's API uses OAuth as an Authentication scheme. Hence, before starting to make requests, you need to get your client credentials to the Spotify API.
#
# To do so, you need to have a Spotify account (free or paid). If you don't have one yet, please create a free account before moving on. Once you do, head over to Spotify for Developers, open your [Dashboard](https://developer.spotify.com/dashboard/) and log in with your account.
#
# ![Dashboard](https://www.dropbox.com/s/cpfepk5fbq6ic5a/dashboard.png?raw=1)
#
# Click on “CREATE AN APP”, choose a name and description for your project and work your way through the checkboxes.
#
# <img src="https://www.dropbox.com/s/afubgs4ar99uh80/app.png?raw=1" width="300">
#
# Don't worry about the actual name and description. The only thing we are interested in is getting the credentials.
#
# ![Credentials](https://www.dropbox.com/s/3mmxxeet61nha4l/credentials.png?raw=1)
#
# Once your App has been created, you should see a “Client ID” and “Client Secret” on the left-hand side. These numbers correspond to your client credentials.

# %% [markdown]
# <div class="alert alert-info">Create two new variables, <b>client_id</b> and <b>client_secret</b>, that store your ID and Key, respectively</div>

# %%
# YOUR CODE HERE
client_id = '262a7bd7ced54a3f8c3897e598e214ef'
client_secret = '360701d35c8e4e6c87cef887a59e3ce1'

# %% [markdown]
# Great! We are good to go. Next step is getting an access token.
#
# ## Getting an access token
#
# In order to access the various endpoints of the Spotify API, we need to pass an access token.
#
# To get one, we need to pass a ```POST``` request with our client credentials. This request will create a token resource in the server and respond back with it. We can build this ```POST``` request using ```requests``` library. remember that this library contains all the different methods available when interacting with an API.
#
# <div class="alert alert-info">Run the following cell to built your POST request</div>

# %%
import requests

# URL for token resource
auth_url = 'https://accounts.spotify.com/api/token'

# request body
params = {'grant_type': 'client_credentials',
          'client_id': client_id,
          'client_secret': client_secret}

# POST the request
auth_response = requests.post(auth_url, params).json()

# %% [markdown]
# <div class="alert alert-info">Retrieve your token from <b>auth_response</b> and save it in a new variable called <b>access_token</b>.</div>

# %%
# YOUR CODE HERE
access_token = auth_response['access_token']
#print(access_token)

# %% [markdown]
# This token is your golden ticket to access Spotify's API. A copy of this string is now stored in the server, so that everytime you make a request to the API the server will check that the token you provide and the one it has in store match.
#
# <img src="https://www.dropbox.com/s/hgb02k4h1mtdv22/header.png?raw=1" width="500">
#
# As opposed to NASA's API, where we provided our API Key as part of the request body, Spotify's API expects you to include your access token in the requests header. There is a specific header called 'Authorization' for this purpose. Providing this information is sometimes tricky. Hence, the header has already been formatted for you.
#
# <div class="alert alert-info">Run the following cell to save the header in a new variable so that you can use it later on.</div>

# %%
headers = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %% [markdown]
# ## Poking around
#
# Spotify's API provides numerous endpoints to access things like album listings, artist information, playlists, even Spotify-generated audio analysis of individual tracks, which include their time signature or measurements such as their “danceability” or "loudness". You can take a look at all the information available by reading the [Docs](https://developer.spotify.com/documentation/web-api/reference/). In this assignment you will use several of these endpoints.
#
# In order to get a feel of how the API works, we will begin by making a ```GET``` request to the ```audio-features``` endpoint to extract data for a specific track. In particular, let's retrieve all the information for Radiohead's *Creep* song.
#
# The first thing you need is to identify the appropriate URL or path to direct your request to. The urls for all Spotify API endpoints follow the same structure. They all use the base URL for the API and are then defined as a concatenation of ```base_url + endpoint```. Sometimes, you will also need to provide some additional information as part of the URL. In the case of ```audio-features```, however, it is enough with just the ```base_url``` and the ```endpoint``` name.
#
# The ```base_url``` is defined below:

# %%
base_url = 'https://api.spotify.com/v1/'

# %% [markdown]
# <div class="alert alert-info">Define the url for the audio-features endpoint by following the instructions above. Store it in a variable called <b>audio_features_endpoint</b>.</div>

# %%
# YOUR CODE HERE
endpoint = 'audio-features'
audio_features_endpoint = base_url + endpoint
#audio_features_endpoint

# %% [markdown]
# Next thing we need is to fill in the request body. If you check the documentation you'll see that the ```audio-features``` endpoint takes the following query parameters.
#
# <img src="https://www.dropbox.com/s/s4zs6wlue0u16cu/body.png?raw=1" width="500">
#
# Hence, the final thing you need to extract data about Radiohead's Creep song is to locate its ```id```. This is its unique identifier. Spotify has unique ids for tracks, for artists, for albums, for playlists, etc.
#
# ![Creep](https://www.dropbox.com/s/kufj6ww2yn069gb/creep.png?raw=1)
#
# You can get the ```id``` for any song by going to Spotify, looking for the song, clicking the “…” by the song name, then “Share” and then “Copy Spotify URI”.
#
# <div class="alert alert-warning">Note that this procedure also works for retrieving ids for artists, albums or any other resource type.</div>
#
# This URI should be a string that includes something like **spotify:track:**, followed by an alphanumeric sequence. This sequence is the ID you are looking for.
#
# <div class="alert alert-info">Create a new variable called <b>track_id</b> that stores the ID for Radiohead's song Creep.</div>

# %%
# YOUR CODE HERE
track_id = '6b2oQwSGFkzsMtQruIWm2p'

# %% [markdown]
# Now that we have the id, let's format the body of our request. As we did for NASA's API, we'll provide the body in dictionary form using a variable called *params*. Remember that the keys of this dictionary should correspond to the different query parameters defined in the documentation.
#
# <div class="alert alert-info">Create a dictionary called <b>params</b> that stores the body of your request. Make sure you format it in the right way.</div>

# %%
# YOUR CODE HERE
params = {'ids' : track_id}

# %% [markdown]
# Now that everything is ready, you can run the actual GET request to retrieve the data.
#
# <div class="alert alert-info">Write the code to make your get request using the requests library. When doing so, remember to pass the <i>url</i>, the <i>headers</i> and the <i>params</i> dictionary as arguments to the <i>get</i> function. Convert the response to <i>json</i> format and store it in a new variable called <b>creep</b>.</div>
#
# <div class="alert alert-warning">If you leave your notebook open for too long, your token might expire. When this happens, you will get an error {'error': {'status': 401, 'message': 'The access token expired'}} when making your request to the server. No worries. Just renew your token by executing the corresponding cell again and you should be good to go</div>

# %%
# YOUR CODE HERE
import requests
creep = requests.get(audio_features_endpoint, headers = headers, params = params).json()
#creep

# %% [markdown]
# You can run the following cell to check if you obtained the right answer. If you get no error when running the cell it means that you did right. Otherwise, revise your code to ensure you get no error. You can run this cell as many times as you want, just **remember not to modify it**.
#
# <div class="alert alert-danger"> Make sure you pass this test successfully before moving on to the remaining exercises.</div>

# %%
import unittest

tc = unittest.TestCase()
tc.assertEqual(creep, {'audio_features': [{'danceability': 0.515,
                                         'energy': 0.43,
                                         'key': 7,
                                         'loudness': -9.935,
                                         'mode': 1,
                                         'speechiness': 0.0369,
                                         'acousticness': 0.0102,
                                         'instrumentalness': 0.000141,
                                         'liveness': 0.129,
                                         'valence': 0.104,
                                         'tempo': 91.841,
                                         'type': 'audio_features',
                                         'id': '6b2oQwSGFkzsMtQruIWm2p',
                                         'uri': 'spotify:track:6b2oQwSGFkzsMtQruIWm2p',
                                         'track_href': 'https://api.spotify.com/v1/tracks/6b2oQwSGFkzsMtQruIWm2p',
                                         'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6b2oQwSGFkzsMtQruIWm2p',
                                         'duration_ms': 238640,
                                         'time_signature': 4}]})

# %% [markdown]
# Congrats! You just made your first successful request to Spotify's API!
#
# Feel free to take a look at the information included in the response. Pay special attention to the way in which information is presented. Once you are done, let's move on to some actual work!
#
# ## Getting data from a playlist
#
# In the following exercise you will build a dataset containing data about different songs. You can either use a playlist of your own, or use the one we have created for this purpose. You can find our playlist in the following [link](https://open.spotify.com/playlist/4NVeFUEHBybfh3ITNG1b8n?si=js9BKt5aTOiCWMm_Cx4Vvg). If you prefer not to use ours, feel free to complete the exercise with a playlist of your choosing.
#
# <div class="alert alert-warning">If you use a playlist of your own, make sure it contains at leats 15 different songs. Preferably from different artists.</div>
#
# <div class="alert alert-info"><b>Exercise 1 </b>Create a variable called <b>playlist_id</b> that stores the id of your playlist of choice.
#     <br><i>[0.5 points]</i></div>

# %%
playlist_id = '4NVeFUEHBybfh3ITNG1b8n'

# %% [markdown]
# The following cells contain the tests that will grade your code. **Don't modify them**. Simply leave them as they are.

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %% [markdown]
# Next step will be making a request to get full details of the tracks included in your chosen playlist. Remember that you can take a look at all the information available at the different endpoints in Spotify's API by reading the [Docs](https://developer.spotify.com/documentation/web-api/reference/). Locate the right endpoint for your query and read the Docs to find out how to build your request.
#
# <div class="alert alert-info"><b>Exercise 2 </b>Write the code to retrieve all the items from your chosen playlist. When making your request don't use any of the optional arguments. Store the raw response in a new variable called <i>playlist_response</i>.
# <br><i>[0.75 points]</i></div>
#
# <div class="alert alert-warning">To complete this exercise you must use the requests library</div>

# %%
# YOUR CODE HERE
import requests
url_playlist = 'https://api.spotify.com/v1/playlists/4NVeFUEHBybfh3ITNG1b8n/tracks'

params = {'playlist_id' : playlist_id}

playlist_response = requests.get(url_playlist, params = params, headers = headers)

# %% [markdown]
# The following cells contain the tests that will grade your code. **Don't modify them**. Simply leave them as they are.

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %% [markdown]
# <div class="alert alert-info"><b>Exercise 3 </b>Convert the response to JSON format and update the variable <i>playlist</i>.<br><i>[0.25 points]</i></div>

# %%
# YOUR CODE HERE
playlist = playlist_response.json()
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4NVeFUEHBybfh3ITNG1b8n/tracks?offset=0&limit=100',
#  'items': [{'added_at': '2020-10-11T08:39:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#        'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#        'id': '4Z8W4fKeB5YxbusRsdQVPb',
#        'name': 'Radiohead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6400dnyeDyD2mIFHfkwHXN'},
#      'href': 'https://api.spotify.com/v1/albums/6400dnyeDyD2mIFHfkwHXN',
#      'id': '6400dnyeDyD2mIFHfkwHXN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732f85b65d3ac4d3d7f806ca11',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022f85b65d3ac4d3d7f806ca11',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512f85b65d3ac4d3d7f806ca11',
#        'width': 64}],
#      'name': 'Pablo Honey',
#      'release_date': '1993-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6400dnyeDyD2mIFHfkwHXN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 238640,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBAYE9200070'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6b2oQwSGFkzsMtQruIWm2p'},
#     'href': 'https://api.spotify.com/v1/tracks/6b2oQwSGFkzsMtQruIWm2p',
#     'id': '6b2oQwSGFkzsMtQruIWm2p',
#     'is_local': False,
#     'name': 'Creep',
#     'popularity': 10,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6b2oQwSGFkzsMtQruIWm2p'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:40:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#        'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#        'id': '4CvTDPKA6W06DRfBnZKrau',
#        'name': 'Thom Yorke',
#        'type': 'artist',
#        'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4QSIeDnAnGag2YZ5DjB2eB'},
#      'href': 'https://api.spotify.com/v1/albums/4QSIeDnAnGag2YZ5DjB2eB',
#      'id': '4QSIeDnAnGag2YZ5DjB2eB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273132e1996896c6bd1ac4e51e8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02132e1996896c6bd1ac4e51e8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851132e1996896c6bd1ac4e51e8',
#        'width': 64}],
#      'name': 'The Eraser',
#      'release_date': '2006-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:4QSIeDnAnGag2YZ5DjB2eB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#       'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#       'id': '4CvTDPKA6W06DRfBnZKrau',
#       'name': 'Thom Yorke',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 289826,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBBKS0600030'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4VbV8Zyjuu1qz0QteX1wVC'},
#     'href': 'https://api.spotify.com/v1/tracks/4VbV8Zyjuu1qz0QteX1wVC',
#     'id': '4VbV8Zyjuu1qz0QteX1wVC',
#     'is_local': False,
#     'name': 'Black Swan',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4VbV8Zyjuu1qz0QteX1wVC'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:40:19Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Eu1txygG6nJttLHbZdQOh'},
#        'href': 'https://api.spotify.com/v1/artists/7Eu1txygG6nJttLHbZdQOh',
#        'id': '7Eu1txygG6nJttLHbZdQOh',
#        'name': 'Four Tet',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Eu1txygG6nJttLHbZdQOh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/74r6JJ97ipO0CREXP9PMqZ'},
#      'href': 'https://api.spotify.com/v1/albums/74r6JJ97ipO0CREXP9PMqZ',
#      'id': '74r6JJ97ipO0CREXP9PMqZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733f31769b727102837cb32a63',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023f31769b727102837cb32a63',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513f31769b727102837cb32a63',
#        'width': 64}],
#      'name': 'New Energy',
#      'release_date': '2017-09-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:74r6JJ97ipO0CREXP9PMqZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Eu1txygG6nJttLHbZdQOh'},
#       'href': 'https://api.spotify.com/v1/artists/7Eu1txygG6nJttLHbZdQOh',
#       'id': '7Eu1txygG6nJttLHbZdQOh',
#       'name': 'Four Tet',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Eu1txygG6nJttLHbZdQOh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 252255,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBXNG1744401'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2ZIaH69kaz55RM4Pjx6KXl'},
#     'href': 'https://api.spotify.com/v1/tracks/2ZIaH69kaz55RM4Pjx6KXl',
#     'id': '2ZIaH69kaz55RM4Pjx6KXl',
#     'is_local': False,
#     'name': 'Two Thousand and Seventeen',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b34e109295596ba611adce3f29ddbc485e2ba777?cid=262a7bd7ced54a3f8c3897e598e214ef',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2ZIaH69kaz55RM4Pjx6KXl'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:40:49Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#        'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#        'id': '4Z8W4fKeB5YxbusRsdQVPb',
#        'name': 'Radiohead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/500FEaUzn8lN9zWFyZG5C2'},
#      'href': 'https://api.spotify.com/v1/albums/500FEaUzn8lN9zWFyZG5C2',
#      'id': '500FEaUzn8lN9zWFyZG5C2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27322ca59e5c2d806439d5f08a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0222ca59e5c2d806439d5f08a2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485122ca59e5c2d806439d5f08a2',
#        'width': 64}],
#      'name': 'The Bends',
#      'release_date': '1995-03-28',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:500FEaUzn8lN9zWFyZG5C2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 257480,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE9400055'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5jafMI8FLibnjkYTZ33m0c'},
#     'href': 'https://api.spotify.com/v1/tracks/5jafMI8FLibnjkYTZ33m0c',
#     'id': '5jafMI8FLibnjkYTZ33m0c',
#     'is_local': False,
#     'name': 'High And Dry',
#     'popularity': 3,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5jafMI8FLibnjkYTZ33m0c'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:40:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#        'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#        'id': '4Z8W4fKeB5YxbusRsdQVPb',
#        'name': 'Radiohead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7dxKtc08dYeRVHt3p9CZJn'},
#      'href': 'https://api.spotify.com/v1/albums/7dxKtc08dYeRVHt3p9CZJn',
#      'id': '7dxKtc08dYeRVHt3p9CZJn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273adb1732fa8d44b8eb2f6c0bf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02adb1732fa8d44b8eb2f6c0bf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851adb1732fa8d44b8eb2f6c0bf',
#        'width': 64}],
#      'name': 'OK Computer',
#      'release_date': '1997-05-28',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7dxKtc08dYeRVHt3p9CZJn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 264066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE9701368'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3SVAN3BRByDmHOhKyIDxfC'},
#     'href': 'https://api.spotify.com/v1/tracks/3SVAN3BRByDmHOhKyIDxfC',
#     'id': '3SVAN3BRByDmHOhKyIDxfC',
#     'is_local': False,
#     'name': 'Karma Police',
#     'popularity': 8,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3SVAN3BRByDmHOhKyIDxfC'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:41:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6liAMWkVf5LH7YR9yfFy1Y'},
#        'href': 'https://api.spotify.com/v1/artists/6liAMWkVf5LH7YR9yfFy1Y',
#        'id': '6liAMWkVf5LH7YR9yfFy1Y',
#        'name': 'Portishead',
#        'type': 'artist',
#        'uri': 'spotify:artist:6liAMWkVf5LH7YR9yfFy1Y'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3539EbNgIdEDGBKkUf4wno'},
#      'href': 'https://api.spotify.com/v1/albums/3539EbNgIdEDGBKkUf4wno',
#      'id': '3539EbNgIdEDGBKkUf4wno',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dc20397b139223620af148f6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dc20397b139223620af148f6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dc20397b139223620af148f6',
#        'width': 64}],
#      'name': 'Dummy',
#      'release_date': '1994-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:3539EbNgIdEDGBKkUf4wno'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6liAMWkVf5LH7YR9yfFy1Y'},
#       'href': 'https://api.spotify.com/v1/artists/6liAMWkVf5LH7YR9yfFy1Y',
#       'id': '6liAMWkVf5LH7YR9yfFy1Y',
#       'name': 'Portishead',
#       'type': 'artist',
#       'uri': 'spotify:artist:6liAMWkVf5LH7YR9yfFy1Y'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 303973,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAQT9400064'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2sW8fmnISifQTRgnRrQTYW'},
#     'href': 'https://api.spotify.com/v1/tracks/2sW8fmnISifQTRgnRrQTYW',
#     'id': '2sW8fmnISifQTRgnRrQTYW',
#     'is_local': False,
#     'name': 'Roads',
#     'popularity': 61,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:2sW8fmnISifQTRgnRrQTYW'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:41:08Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6liAMWkVf5LH7YR9yfFy1Y'},
#        'href': 'https://api.spotify.com/v1/artists/6liAMWkVf5LH7YR9yfFy1Y',
#        'id': '6liAMWkVf5LH7YR9yfFy1Y',
#        'name': 'Portishead',
#        'type': 'artist',
#        'uri': 'spotify:artist:6liAMWkVf5LH7YR9yfFy1Y'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3539EbNgIdEDGBKkUf4wno'},
#      'href': 'https://api.spotify.com/v1/albums/3539EbNgIdEDGBKkUf4wno',
#      'id': '3539EbNgIdEDGBKkUf4wno',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dc20397b139223620af148f6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dc20397b139223620af148f6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dc20397b139223620af148f6',
#        'width': 64}],
#      'name': 'Dummy',
#      'release_date': '1994-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:3539EbNgIdEDGBKkUf4wno'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6liAMWkVf5LH7YR9yfFy1Y'},
#       'href': 'https://api.spotify.com/v1/artists/6liAMWkVf5LH7YR9yfFy1Y',
#       'id': '6liAMWkVf5LH7YR9yfFy1Y',
#       'name': 'Portishead',
#       'type': 'artist',
#       'uri': 'spotify:artist:6liAMWkVf5LH7YR9yfFy1Y'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 308626,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAQT9400066'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Ty7OTBNSigGEpeW2PqcsC'},
#     'href': 'https://api.spotify.com/v1/tracks/3Ty7OTBNSigGEpeW2PqcsC',
#     'id': '3Ty7OTBNSigGEpeW2PqcsC',
#     'is_local': False,
#     'name': 'Glory Box',
#     'popularity': 68,
#     'preview_url': None,
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:3Ty7OTBNSigGEpeW2PqcsC'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:41:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FXMGgJwohJLUSr5nVlf9X'},
#        'href': 'https://api.spotify.com/v1/artists/6FXMGgJwohJLUSr5nVlf9X',
#        'id': '6FXMGgJwohJLUSr5nVlf9X',
#        'name': 'Massive Attack',
#        'type': 'artist',
#        'uri': 'spotify:artist:6FXMGgJwohJLUSr5nVlf9X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/49MNmJhZQewjt06rpwp6QR'},
#      'href': 'https://api.spotify.com/v1/albums/49MNmJhZQewjt06rpwp6QR',
#      'id': '49MNmJhZQewjt06rpwp6QR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732fcb0a3c7a66e516b11cd26e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022fcb0a3c7a66e516b11cd26e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512fcb0a3c7a66e516b11cd26e',
#        'width': 64}],
#      'name': 'Mezzanine',
#      'release_date': '1998-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:49MNmJhZQewjt06rpwp6QR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FXMGgJwohJLUSr5nVlf9X'},
#       'href': 'https://api.spotify.com/v1/artists/6FXMGgJwohJLUSr5nVlf9X',
#       'id': '6FXMGgJwohJLUSr5nVlf9X',
#       'name': 'Massive Attack',
#       'type': 'artist',
#       'uri': 'spotify:artist:6FXMGgJwohJLUSr5nVlf9X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 330773,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAAA9800322'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/67Hna13dNDkZvBpTXRIaOJ'},
#     'href': 'https://api.spotify.com/v1/tracks/67Hna13dNDkZvBpTXRIaOJ',
#     'id': '67Hna13dNDkZvBpTXRIaOJ',
#     'is_local': False,
#     'name': 'Teardrop',
#     'popularity': 68,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:67Hna13dNDkZvBpTXRIaOJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:41:21Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FXMGgJwohJLUSr5nVlf9X'},
#        'href': 'https://api.spotify.com/v1/artists/6FXMGgJwohJLUSr5nVlf9X',
#        'id': '6FXMGgJwohJLUSr5nVlf9X',
#        'name': 'Massive Attack',
#        'type': 'artist',
#        'uri': 'spotify:artist:6FXMGgJwohJLUSr5nVlf9X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1F8y2bg9V9nRoy8zuxo3Jt'},
#      'href': 'https://api.spotify.com/v1/albums/1F8y2bg9V9nRoy8zuxo3Jt',
#      'id': '1F8y2bg9V9nRoy8zuxo3Jt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273852aaa233e122f1dbfefcf00',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02852aaa233e122f1dbfefcf00',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851852aaa233e122f1dbfefcf00',
#        'width': 64}],
#      'name': 'Heligoland',
#      'release_date': '2010-02-08',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1F8y2bg9V9nRoy8zuxo3Jt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FXMGgJwohJLUSr5nVlf9X'},
#       'href': 'https://api.spotify.com/v1/artists/6FXMGgJwohJLUSr5nVlf9X',
#       'id': '6FXMGgJwohJLUSr5nVlf9X',
#       'name': 'Massive Attack',
#       'type': 'artist',
#       'uri': 'spotify:artist:6FXMGgJwohJLUSr5nVlf9X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 297774,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAAA0900963'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2BndJYJQ17UcEeUFJP5JmY'},
#     'href': 'https://api.spotify.com/v1/tracks/2BndJYJQ17UcEeUFJP5JmY',
#     'id': '2BndJYJQ17UcEeUFJP5JmY',
#     'is_local': False,
#     'name': 'Paradise Circus',
#     'popularity': 61,
#     'preview_url': None,
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:2BndJYJQ17UcEeUFJP5JmY'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:41:40Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nPOO9iTcrs9k6yFffPxjH'},
#        'href': 'https://api.spotify.com/v1/artists/5nPOO9iTcrs9k6yFffPxjH',
#        'id': '5nPOO9iTcrs9k6yFffPxjH',
#        'name': 'Röyksopp',
#        'type': 'artist',
#        'uri': 'spotify:artist:5nPOO9iTcrs9k6yFffPxjH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1HkKeOklBwC1auQJ5Huwcm'},
#      'href': 'https://api.spotify.com/v1/albums/1HkKeOklBwC1auQJ5Huwcm',
#      'id': '1HkKeOklBwC1auQJ5Huwcm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27324850f3eb04b5132b96df67a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0224850f3eb04b5132b96df67a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485124850f3eb04b5132b96df67a',
#        'width': 64}],
#      'name': 'The Understanding',
#      'release_date': '2005-06-22',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:1HkKeOklBwC1auQJ5Huwcm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nPOO9iTcrs9k6yFffPxjH'},
#       'href': 'https://api.spotify.com/v1/artists/5nPOO9iTcrs9k6yFffPxjH',
#       'id': '5nPOO9iTcrs9k6yFffPxjH',
#       'name': 'Röyksopp',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nPOO9iTcrs9k6yFffPxjH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
# ...
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4EFkiDiipLkTPtUkmXrtrk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Z7gV3uEh1ckIaBzTUCE6R'},
#       'href': 'https://api.spotify.com/v1/artists/2Z7gV3uEh1ckIaBzTUCE6R',
#       'id': '2Z7gV3uEh1ckIaBzTUCE6R',
#       'name': 'Conor Oberst',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Z7gV3uEh1ckIaBzTUCE6R'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'BA',
#      'BD',
#      'BE',
#      'BO',
#      'BR',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GN',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KH',
#      'KR',
#      'LA',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MU',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 244173,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMRG0834001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5RlSc9SkmmV1Ma4Hd7TQYZ'},
#     'href': 'https://api.spotify.com/v1/tracks/5RlSc9SkmmV1Ma4Hd7TQYZ',
#     'id': '5RlSc9SkmmV1Ma4Hd7TQYZ',
#     'is_local': False,
#     'name': 'Cape Canaveral',
#     'popularity': 26,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5RlSc9SkmmV1Ma4Hd7TQYZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:54:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4M5nCE77Qaxayuhp3fVn4V'},
#        'href': 'https://api.spotify.com/v1/artists/4M5nCE77Qaxayuhp3fVn4V',
#        'id': '4M5nCE77Qaxayuhp3fVn4V',
#        'name': 'Iron & Wine',
#        'type': 'artist',
#        'uri': 'spotify:artist:4M5nCE77Qaxayuhp3fVn4V'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4sgupIgP8AaivCBO5gXA2g'},
#      'href': 'https://api.spotify.com/v1/albums/4sgupIgP8AaivCBO5gXA2g',
#      'id': '4sgupIgP8AaivCBO5gXA2g',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27378b096b266e140d924726b23',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0278b096b266e140d924726b23',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485178b096b266e140d924726b23',
#        'width': 64}],
#      'name': 'Around The Well',
#      'release_date': '2009-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 23,
#      'type': 'album',
#      'uri': 'spotify:album:4sgupIgP8AaivCBO5gXA2g'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4M5nCE77Qaxayuhp3fVn4V'},
#       'href': 'https://api.spotify.com/v1/artists/4M5nCE77Qaxayuhp3fVn4V',
#       'id': '4M5nCE77Qaxayuhp3fVn4V',
#       'name': 'Iron & Wine',
#       'type': 'artist',
#       'uri': 'spotify:artist:4M5nCE77Qaxayuhp3fVn4V'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 251280,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSUB0400034'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7vcuTZAFyu0Z5dgMRLR0h0'},
#     'href': 'https://api.spotify.com/v1/tracks/7vcuTZAFyu0Z5dgMRLR0h0',
#     'id': '7vcuTZAFyu0Z5dgMRLR0h0',
#     'is_local': False,
#     'name': 'Such Great Heights',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:7vcuTZAFyu0Z5dgMRLR0h0'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:54:58Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05TeWWFqSVEUurt1lVhh4q'},
#        'href': 'https://api.spotify.com/v1/artists/05TeWWFqSVEUurt1lVhh4q',
#        'id': '05TeWWFqSVEUurt1lVhh4q',
#        'name': 'Lou Doillon',
#        'type': 'artist',
#        'uri': 'spotify:artist:05TeWWFqSVEUurt1lVhh4q'}],
#      'available_markets': ['AR',
#       'AT',
#       'BE',
#       'BR',
#       'CH',
#       'DK',
#       'ES',
#       'FI',
#       'FR',
#       'IT',
#       'LU',
#       'NL',
#       'SE'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Nww4I0GG6LOfdvjy6ypCu'},
#      'href': 'https://api.spotify.com/v1/albums/1Nww4I0GG6LOfdvjy6ypCu',
#      'id': '1Nww4I0GG6LOfdvjy6ypCu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736a75f8638a207f8cb29ef060',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026a75f8638a207f8cb29ef060',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516a75f8638a207f8cb29ef060',
#        'width': 64}],
#      'name': 'Places',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1Nww4I0GG6LOfdvjy6ypCu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05TeWWFqSVEUurt1lVhh4q'},
#       'href': 'https://api.spotify.com/v1/artists/05TeWWFqSVEUurt1lVhh4q',
#       'id': '05TeWWFqSVEUurt1lVhh4q',
#       'name': 'Lou Doillon',
#       'type': 'artist',
#       'uri': 'spotify:artist:05TeWWFqSVEUurt1lVhh4q'}],
#     'available_markets': ['AR',
#      'AT',
#      'BE',
#      'BR',
#      'CH',
#      'DK',
#      'ES',
#      'FI',
#      'FR',
#      'IT',
#      'LU',
#      'NL',
#      'SE'],
#     'disc_number': 1,
#     'duration_ms': 244280,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRUM71201349'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2B0vzJSvp2Y0Bx8HUN4jyT'},
#     'href': 'https://api.spotify.com/v1/tracks/2B0vzJSvp2Y0Bx8HUN4jyT',
#     'id': '2B0vzJSvp2Y0Bx8HUN4jyT',
#     'is_local': False,
#     'name': 'Devil Or Angel',
#     'popularity': 39,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2B0vzJSvp2Y0Bx8HUN4jyT'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:55:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/44NX2ffIYHr6D4n7RaZF7A'},
#        'href': 'https://api.spotify.com/v1/artists/44NX2ffIYHr6D4n7RaZF7A',
#        'id': '44NX2ffIYHr6D4n7RaZF7A',
#        'name': 'Van Morrison',
#        'type': 'artist',
#        'uri': 'spotify:artist:44NX2ffIYHr6D4n7RaZF7A'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5PfnCqRbdfIDMb1x3MPQam'},
#      'href': 'https://api.spotify.com/v1/albums/5PfnCqRbdfIDMb1x3MPQam',
#      'id': '5PfnCqRbdfIDMb1x3MPQam',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d828b182ee9b7193a0f8b5d6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d828b182ee9b7193a0f8b5d6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d828b182ee9b7193a0f8b5d6',
#        'width': 64}],
#      'name': 'Moondance',
#      'release_date': '1970-02',
#      'release_date_precision': 'month',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5PfnCqRbdfIDMb1x3MPQam'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/44NX2ffIYHr6D4n7RaZF7A'},
#       'href': 'https://api.spotify.com/v1/artists/44NX2ffIYHr6D4n7RaZF7A',
#       'id': '44NX2ffIYHr6D4n7RaZF7A',
#       'name': 'Van Morrison',
#       'type': 'artist',
#       'uri': 'spotify:artist:44NX2ffIYHr6D4n7RaZF7A'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 205613,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB11302507'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3lh3iiiJeiBXHSZw6u0kh6'},
#     'href': 'https://api.spotify.com/v1/tracks/3lh3iiiJeiBXHSZw6u0kh6',
#     'id': '3lh3iiiJeiBXHSZw6u0kh6',
#     'is_local': False,
#     'name': 'Into the Mystic - 2013 Remaster',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e80d5c0efd271bd14f752d6c7ef11202e89d29f1?cid=262a7bd7ced54a3f8c3897e598e214ef',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:3lh3iiiJeiBXHSZw6u0kh6'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-10-11T08:55:14Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/niakha'},
#     'href': 'https://api.spotify.com/v1/users/niakha',
#     'id': 'niakha',
#     'type': 'user',
#     'uri': 'spotify:user:niakha'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/79JJCxCCfJ8HufX6w8q2k4'},
#        'href': 'https://api.spotify.com/v1/artists/79JJCxCCfJ8HufX6w8q2k4',
#        'id': '79JJCxCCfJ8HufX6w8q2k4',
#        'name': 'Damien Jurado',
#        'type': 'artist',
#        'uri': 'spotify:artist:79JJCxCCfJ8HufX6w8q2k4'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6tHOCtP4zbc3tNAklAKSUU'},
#      'href': 'https://api.spotify.com/v1/albums/6tHOCtP4zbc3tNAklAKSUU',
#      'id': '6tHOCtP4zbc3tNAklAKSUU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739019622df9136d400d9f39b9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029019622df9136d400d9f39b9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519019622df9136d400d9f39b9',
#        'width': 64}],
#      'name': 'Caught In The Trees',
#      'release_date': '2008-09-09',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:6tHOCtP4zbc3tNAklAKSUU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/79JJCxCCfJ8HufX6w8q2k4'},
#       'href': 'https://api.spotify.com/v1/artists/79JJCxCCfJ8HufX6w8q2k4',
#       'id': '79JJCxCCfJ8HufX6w8q2k4',
#       'name': 'Damien Jurado',
#       'type': 'artist',
#       'uri': 'spotify:artist:79JJCxCCfJ8HufX6w8q2k4'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 256173,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'US38W0817510'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5V4NlIfbLfR5c8U9330HY8'},
#     'href': 'https://api.spotify.com/v1/tracks/5V4NlIfbLfR5c8U9330HY8',
#     'id': '5V4NlIfbLfR5c8U9330HY8',
#     'is_local': False,
#     'name': 'Sheets',
#     'popularity': 39,
#     'preview_url': None,
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:5V4NlIfbLfR5c8U9330HY8'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/4NVeFUEHBybfh3ITNG1b8n/tracks?offset=100&limit=100',
#  'offset': 0,
#  'previous': None,
#  'total': 163}

# %% [markdown]
# The following cells contain the tests that will grade your code. **Don't modify them**. Simply leave them as they are.

# %%
# LEAVE BLANK

# %% [markdown]
# Take your time to familiarize yourself with the data and how they are presented. Note that, by default, Spotify's API only returns information about a maximum of 100 tracks in a playlist. If your playlist of choice has more that 100 tracks, you'll retrieve the data only for the first 100 of them.
#
# <div class="alert alert-danger">Throghout the following exercises you may come across data that are missing. If so, encode these data using a <b>None</b>. </div>
#
# ## Retrieving basic track information
#
# In what follows, you are going to retrieve specific data for each of the tracks contained in your playlist.
#
# <div class="alert alert-info"><b>Exercise 4 </b>Write the code to extract the title (in string form), the name of the album (in string form), the name of the artist (in string form), the duration (in integer form), the track number (in integer form), the release date (in string form), the popularity (in integer form), the id (in string form) and the number of available markets (in integer form) for all the tracks included in your chosen playlist. Store these data in separate lists called <i>title</i>, <i>album</i>, <i>artist</i>, <i>duration</i>, <i>track_number</i>, <i>release_date</i>, <i>track_popularity</i>, <i>track_id</i> and <i>n_available_markets</i>, respectively. In those cases where more than one value is available for these items, retain only the first. In all cases, entries should appear in the same order as they are presented in the playlist.<br><i>[1.5 points]</i></div>
#
# <div class="alert alert-warning">Make sure you correctly set all variable names. They have to be written <b>exactly</b> as given in the instructions.</div>

# %%
# YOUR CODE HERE
title = [] #string
album = [] #string
artist = [] #string
duration = [] #int
track_number = [] #int
release_date = [] #string
track_popularity = [] #int
track_id = [] #string
n_available_markets = [] #int

for element in playlist['items']:
    for key in element['track']:
        if key == 'duration_ms':
            duration.append(element['track'][key])
        elif key == 'id':
            track_id.append(element['track'][key])
        elif key == 'name':
            title.append(element['track'][key])
        elif key == 'popularity':
            track_popularity.append(element['track'][key])
        elif key == 'track_number':
            track_number.append(element['track'][key])
        elif key == 'album':
            album.append(element['track'][key]['name'])
            release_date.append(element['track'][key]['release_date'])
        elif key == 'artists':
            artist.append(element['track'][key][0]['name'])
        elif key == 'available_markets':
            n_available_markets.append(len(element['track'][key]))

#turn 0 in to None
for index, item in enumerate(n_available_markets):
    if item == 0:
        n_available_markets[index] = None


#check data types
#type(title[1]),type(album[1]),type(artist[1]),type(duration[1]),type(track_number[1]),type(release_date[1]),type(track_popularity[1]),type(track_id[1]),type(n_available_markets[1])

# %% [markdown]
# The following cells check whether your code is correct. Please **don't write any code here**. Just leave them as they are.

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %% [markdown]
# ## Retrieving additional track information
#
# In what follows, you are going to retrieve additional data for each of the tracks contained in your playlist.
#
# <div class="alert alert-info"><b>Exercise 5 </b>Write the code to extract data about the danceability, energy, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence and tempo for all the tracks included in your chosen playlist. Store these data in separate lists called <i>danceability</i> (in float form), <i>energy</i>, <i>loudness</i> (in float form), <i>mode</i> (in int form), <i>speechiness</i> (in float form), <i>acousticness</i> (in float form), <i>instrulmentalness</i> (in int and float form), <i>liveness</i> (in float form), <i>valence</i> (in float form) and <i>tempo</i> (in float form), respectively. In those cases where more than one value is available for these items, retain only the first. In all cases, entries should appear in the same order as they are presented in the playlist.<br><i>[2 points]</i></div>

# %%
# YOUR CODE HERE
track_ids_str = [] #string with all track ids separated by commas

#join all track ids into a single string, separating each element with a comma
track_ids_str = ','.join(track_id)

#use list track_ids_str as input for params
url_playlist_5 = 'https://api.spotify.com/v1/audio-features'

params = {'ids' : track_ids_str}

response_5 = requests.get(url_playlist_5, params = params, headers = headers).json()
#check length of response
#len(response_5['audio_features'])
#response_5

# %%
iteration_list = response_5['audio_features']

# %%
danceability = [] #float
energy = [] #float
loudness = [] #float
mode = [] #int
speechiness = [] #float form)
acousticness = [] #float form)
instrumentalness = [] #int and float form
liveness = [] #float
valence = [] #float
tempo = [] #float

for item in iteration_list: 
    #extract danceability
    danceability.append(item['danceability'])
    
    #extract energy
    energy.append(item['energy'])
    
    #extract loudness
    loudness.append(item['loudness'])
    
    #extract mode
    mode.append(item['mode'])
    
    #extract speechiness
    speechiness.append(item['speechiness'])
    
    #extract acousticness
    acousticness.append(item['acousticness'])
    
    #extract instrumentalness 
    instrumentalness.append(item['instrumentalness'])
    
    #extract liveliness
    liveness.append(item['liveness'])
    
    #extract valence
    valence.append(item['valence'])
    
    #extract tempo
    tempo.append(item['tempo'])

#print(danceability, '\n', energy, '\n', loudness, '\n',  mode, '\n',  speechiness, '\n',  acousticness, '\n',  instrumentalness, '\n',  liveness,  '\n', valence,  '\n', tempo)

# %% [markdown]
# The following cells check whether your code is correct. Please **don't write any code here**. Just leave them as they are.

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %% [markdown]
# ## Retrieving artist information
#
# In what follows, you are going to retrieve data about the artists for each of the tracks contained in your playlist.
#
# <div class="alert alert-info"><b>Exercise 6 </b>Write the code to extract data about the total number of followers (in int form), the first listed genre (in string form) and the popularity (in int form) for the artists of all the tracks included in your chosen playlist. Store these data in separate lists called <i>artist_followers</i>, <i>genre</i> and <i>artist_popularity</i>. In cases where no genre is given, fill in the corresponding entry using a None.<br><i>[1.5 points]</i></div>

# %%
# YOUR CODE HERE
#find the artist IDs for the relevant artists
artist_ids = []

relevant_list = playlist['items']
for each_element in relevant_list:
    artist_ids.append(each_element['track']['artists'][0]['id'])

# %%
artist_ids_1 = []
artist_ids_2 = []

#divide artist_id into two lists of 50 elements each
half_length = int(len(artist_ids)/2)

artist_ids_1 = artist_ids[:half_length]
artist_ids_2 = artist_ids[half_length:]

#unify all ids into 2 strings, separating the ids with commas
artist_ids_1_str = ','.join(artist_ids_1)
artist_ids_2_str = ','.join(artist_ids_2)

# %%
#retrieve first 50 artists
url_artists = 'https://api.spotify.com/v1/artists'

params = {'ids' : artist_ids_1_str}

first_50 = requests.get(url_artists, params = params, headers = headers).json()

# %%
#retrieve second 50 artists
params = {'ids' : artist_ids_2_str}

second_50 = requests.get(url_artists, params = params, headers = headers).json()
second_50
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2BpAc5eK7Rz5GAwSp9UYXa'},
#    'followers': {'href': None, 'total': 598359},
#    'genres': ['indie folk',
#     'stomp and holler',
#     'swedish americana',
#     'swedish singer-songwriter'],
#    'href': 'https://api.spotify.com/v1/artists/2BpAc5eK7Rz5GAwSp9UYXa',
#    'id': '2BpAc5eK7Rz5GAwSp9UYXa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebe790a3bccaa22e827475113b',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174e790a3bccaa22e827475113b',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178e790a3bccaa22e827475113b',
#      'width': 160}],
#    'name': 'The Tallest Man On Earth',
#    'popularity': 57,
#    'type': 'artist',
#    'uri': 'spotify:artist:2BpAc5eK7Rz5GAwSp9UYXa'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#    'followers': {'href': None, 'total': 5150777},
#    'genres': ['australian psych', 'neo-psychedelic'],
#    'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#    'id': '5INjqkS1o8h1imAzPqGZBb',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb5a2dadeff50fa5c9ad9365c9',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051745a2dadeff50fa5c9ad9365c9',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1785a2dadeff50fa5c9ad9365c9',
#      'width': 160}],
#    'name': 'Tame Impala',
#    'popularity': 79,
#    'type': 'artist',
#    'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2rBcvLKWCZs9w1qIWv560v'},
#    'followers': {'href': None, 'total': 191498},
#    'genres': ['art pop', 'electronica'],
#    'href': 'https://api.spotify.com/v1/artists/2rBcvLKWCZs9w1qIWv560v',
#    'id': '2rBcvLKWCZs9w1qIWv560v',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb5c6941ccec946b6e52c87362',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051745c6941ccec946b6e52c87362',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1785c6941ccec946b6e52c87362',
#      'width': 160}],
#    'name': 'Charlotte Gainsbourg',
#    'popularity': 48,
#    'type': 'artist',
#    'uri': 'spotify:artist:2rBcvLKWCZs9w1qIWv560v'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'},
#    'followers': {'href': None, 'total': 15472234},
#    'genres': ['album rock',
#     'art rock',
#     'classic rock',
#     'progressive rock',
#     'psychedelic rock',
#     'rock',
#     'symphonic rock'],
#    'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9',
#    'id': '0k17h0D3J5VfsdmQ1iZtE9',
#    'images': [{'height': 977,
#      'url': 'https://i.scdn.co/image/e69f71e2be4b67b82af90fb8e9d805715e0684fa',
#      'width': 1000},
#     {'height': 625,
#      'url': 'https://i.scdn.co/image/d011c95081cd9a329e506abd7ded47535d524a07',
#      'width': 640},
#     {'height': 195,
#      'url': 'https://i.scdn.co/image/f0a39a8a196a87a7236bdcf8a8708f6d5d3547cc',
#      'width': 200},
#     {'height': 63,
#      'url': 'https://i.scdn.co/image/ec1fb7127168dbaa962404031409c5a293b95ec6',
#      'width': 64}],
#    'name': 'Pink Floyd',
#    'popularity': 80,
#    'type': 'artist',
#    'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0WwSkZ7LtFUFjGjMZBMt6T'},
#    'followers': {'href': None, 'total': 5079462},
#    'genres': ['album rock', 'classic rock', 'mellow gold', 'rock'],
#    'href': 'https://api.spotify.com/v1/artists/0WwSkZ7LtFUFjGjMZBMt6T',
#    'id': '0WwSkZ7LtFUFjGjMZBMt6T',
#    'images': [{'height': 1021,
#      'url': 'https://i.scdn.co/image/54a86ecf1de16b17e2ed000a9ca8a1590c9a3b80',
#      'width': 1000},
#     {'height': 653,
#      'url': 'https://i.scdn.co/image/caf04a8a030c70dd697ee0b37562033bbe3cdb4f',
#      'width': 640},
#     {'height': 204,
#      'url': 'https://i.scdn.co/image/7756c61bed0dc7650b188a4c7be984dc4e1d7651',
#      'width': 200},
#     {'height': 65,
#      'url': 'https://i.scdn.co/image/0ba7e13266153e59b9b611cbd43e21aec7f6737c',
#      'width': 64}],
#    'name': 'Dire Straits',
#    'popularity': 76,
#    'type': 'artist',
#    'uri': 'spotify:artist:0WwSkZ7LtFUFjGjMZBMt6T'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/432R46LaYsJZV2Gmc4jUV5'},
#    'followers': {'href': None, 'total': 1737458},
#    'genres': ['alternative rock',
#     'art rock',
#     'madchester',
#     'new wave',
#     'post-punk',
#     'rock',
#     'uk post-punk'],
#    'href': 'https://api.spotify.com/v1/artists/432R46LaYsJZV2Gmc4jUV5',
#    'id': '432R46LaYsJZV2Gmc4jUV5',
#    'images': [{'height': 658,
#      'url': 'https://i.scdn.co/image/5eeddd733170399db794d2c430a8d2cde7ae1425',
#      'width': 1000},
#     {'height': 421,
#      'url': 'https://i.scdn.co/image/d3c6bcb07a5ecddf86e791fa901bf3792fe6e6c7',
#      'width': 640},
#     {'height': 132,
#      'url': 'https://i.scdn.co/image/d384ebd3d3fda0ad219fed6b9014a59e65fbb385',
#      'width': 200},
#     {'height': 42,
#      'url': 'https://i.scdn.co/image/1b5195d5e9b5aac07fb0c801deb1926138222036',
#      'width': 64}],
#    'name': 'Joy Division',
#    'popularity': 65,
#    'type': 'artist',
#    'uri': 'spotify:artist:432R46LaYsJZV2Gmc4jUV5'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#    'followers': {'href': None, 'total': 10814125},
#    'genres': ['british invasion', 'classic rock', 'rock'],
#    'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#    'id': '22bE4uQ6baNwSHPVcDxLCe',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebd3cb15a8570cce5a63af63d8',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174d3cb15a8570cce5a63af63d8',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178d3cb15a8570cce5a63af63d8',
#      'width': 160}],
#    'name': 'The Rolling Stones',
#    'popularity': 81,
#    'type': 'artist',
#    'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LEiUm1SRbFMgfqnQTwUbQ'},
#    'followers': {'href': None, 'total': 3061747},
#    'genres': ['eau claire indie', 'indie folk', 'melancholia'],
#    'href': 'https://api.spotify.com/v1/artists/4LEiUm1SRbFMgfqnQTwUbQ',
#    'id': '4LEiUm1SRbFMgfqnQTwUbQ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb67be065df01f37a3880216be',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517467be065df01f37a3880216be',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17867be065df01f37a3880216be',
#      'width': 160}],
#    'name': 'Bon Iver',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:4LEiUm1SRbFMgfqnQTwUbQ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LEiUm1SRbFMgfqnQTwUbQ'},
#    'followers': {'href': None, 'total': 3061747},
#    'genres': ['eau claire indie', 'indie folk', 'melancholia'],
#    'href': 'https://api.spotify.com/v1/artists/4LEiUm1SRbFMgfqnQTwUbQ',
#    'id': '4LEiUm1SRbFMgfqnQTwUbQ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb67be065df01f37a3880216be',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517467be065df01f37a3880216be',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17867be065df01f37a3880216be',
#      'width': 160}],
#    'name': 'Bon Iver',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:4LEiUm1SRbFMgfqnQTwUbQ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LEiUm1SRbFMgfqnQTwUbQ'},
#    'followers': {'href': None, 'total': 3061747},
#    'genres': ['eau claire indie', 'indie folk', 'melancholia'],
#    'href': 'https://api.spotify.com/v1/artists/4LEiUm1SRbFMgfqnQTwUbQ',
#    'id': '4LEiUm1SRbFMgfqnQTwUbQ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb67be065df01f37a3880216be',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517467be065df01f37a3880216be',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17867be065df01f37a3880216be',
#      'width': 160}],
#    'name': 'Bon Iver',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:4LEiUm1SRbFMgfqnQTwUbQ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LEiUm1SRbFMgfqnQTwUbQ'},
#    'followers': {'href': None, 'total': 3061747},
#    'genres': ['eau claire indie', 'indie folk', 'melancholia'],
#    'href': 'https://api.spotify.com/v1/artists/4LEiUm1SRbFMgfqnQTwUbQ',
#    'id': '4LEiUm1SRbFMgfqnQTwUbQ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb67be065df01f37a3880216be',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517467be065df01f37a3880216be',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17867be065df01f37a3880216be',
#      'width': 160}],
#    'name': 'Bon Iver',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:4LEiUm1SRbFMgfqnQTwUbQ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0OdUWJ0sBjDrqHygGUXeCF'},
#    'followers': {'href': None, 'total': 893990},
#    'genres': ['indie folk',
#     'indie pop',
#     'indie rock',
#     'modern rock',
#     'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/0OdUWJ0sBjDrqHygGUXeCF',
#    'id': '0OdUWJ0sBjDrqHygGUXeCF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb61547959a3bf5330ffa42ddf',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517461547959a3bf5330ffa42ddf',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17861547959a3bf5330ffa42ddf',
#      'width': 160}],
#    'name': 'Band of Horses',
#    'popularity': 61,
#    'type': 'artist',
#    'uri': 'spotify:artist:0OdUWJ0sBjDrqHygGUXeCF'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6xrCU6zdcSTsG2hLrojpmI'},
#    'followers': {'href': None, 'total': 950407},
#    'genres': ['gothenburg indie',
#     'indie folk',
#     'neo mellow',
#     'stomp and holler',
#     'swedish indie folk',
#     'swedish indie pop',
#     'swedish singer-songwriter'],
#    'href': 'https://api.spotify.com/v1/artists/6xrCU6zdcSTsG2hLrojpmI',
#    'id': '6xrCU6zdcSTsG2hLrojpmI',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebdb7c07bb0c0ff17cddf8bc0a',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174db7c07bb0c0ff17cddf8bc0a',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178db7c07bb0c0ff17cddf8bc0a',
#      'width': 160}],
#    'name': 'José González',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:6xrCU6zdcSTsG2hLrojpmI'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tvKz56Tr39bkhcQUTO0Xr'},
#    'followers': {'href': None, 'total': 1137207},
#    'genres': ['australian indie folk', 'indie folk', 'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/4tvKz56Tr39bkhcQUTO0Xr',
#    'id': '4tvKz56Tr39bkhcQUTO0Xr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb6991d9d87155e48247e2caf0',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051746991d9d87155e48247e2caf0',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1786991d9d87155e48247e2caf0',
#      'width': 160}],
#    'name': 'Angus & Julia Stone',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:4tvKz56Tr39bkhcQUTO0Xr'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tvKz56Tr39bkhcQUTO0Xr'},
#    'followers': {'href': None, 'total': 1137207},
#    'genres': ['australian indie folk', 'indie folk', 'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/4tvKz56Tr39bkhcQUTO0Xr',
#    'id': '4tvKz56Tr39bkhcQUTO0Xr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb6991d9d87155e48247e2caf0',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051746991d9d87155e48247e2caf0',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1786991d9d87155e48247e2caf0',
#      'width': 160}],
#    'name': 'Angus & Julia Stone',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:4tvKz56Tr39bkhcQUTO0Xr'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4EVpmkEwrLYEg6jIsiPMIb'},
#    'followers': {'href': None, 'total': 1148321},
#    'genres': ['folk',
#     'indie folk',
#     'indie pop',
#     'indie rock',
#     'seattle indie',
#     'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/4EVpmkEwrLYEg6jIsiPMIb',
#    'id': '4EVpmkEwrLYEg6jIsiPMIb',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb9a991823b99766aeb777343f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051749a991823b99766aeb777343f',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1789a991823b99766aeb777343f',
#      'width': 160}],
#    'name': 'Fleet Foxes',
#    'popularity': 67,
#    'type': 'artist',
#    'uri': 'spotify:artist:4EVpmkEwrLYEg6jIsiPMIb'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Bd1cgCjtCI32PYvDC3ynO'},
#    'followers': {'href': None, 'total': 1281041},
#    'genres': ['metropopolis', 'nottingham indie'],
#    'href': 'https://api.spotify.com/v1/artists/3Bd1cgCjtCI32PYvDC3ynO',
#    'id': '3Bd1cgCjtCI32PYvDC3ynO',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb5cdc6c97f01c4d7b786d1e76',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051745cdc6c97f01c4d7b786d1e76',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1785cdc6c97f01c4d7b786d1e76',
#      'width': 160}],
#    'name': 'London Grammar',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:3Bd1cgCjtCI32PYvDC3ynO'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/74ASZWbe4lXaubB36ztrGX'},
#    'followers': {'href': None, 'total': 5288343},
#    'genres': ['album rock',
#     'classic rock',
#     'country rock',
#     'folk',
#     'folk rock',
#     'mellow gold',
#     'rock',
#     'roots rock',
#     'singer-songwriter'],
#    'href': 'https://api.spotify.com/v1/artists/74ASZWbe4lXaubB36ztrGX',
#    'id': '74ASZWbe4lXaubB36ztrGX',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/ab6772690000c46cf79ca05dcc1581c712bf3658',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/ab6772690000dd22f79ca05dcc1581c712bf3658',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/ab6772690000bac3f79ca05dcc1581c712bf3658',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67726900008f74f79ca05dcc1581c712bf3658',
#      'width': 64}],
#    'name': 'Bob Dylan',
#    'popularity': 74,
#    'type': 'artist',
#    'uri': 'spotify:artist:74ASZWbe4lXaubB36ztrGX'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5schNIzWdI9gJ1QRK8SBnc'},
#    'followers': {'href': None, 'total': 1907737},
#    'genres': ['british singer-songwriter',
#     'folk-pop',
#     'indie folk',
#     'neo mellow',
#     'pop rock',
#     'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/5schNIzWdI9gJ1QRK8SBnc',
#    'id': '5schNIzWdI9gJ1QRK8SBnc',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb7f6d3ce714aba5b2c38212dc',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051747f6d3ce714aba5b2c38212dc',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1787f6d3ce714aba5b2c38212dc',
#      'width': 160}],
#    'name': 'Ben Howard',
#    'popularity': 69,
#    'type': 'artist',
#    'uri': 'spotify:artist:5schNIzWdI9gJ1QRK8SBnc'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5schNIzWdI9gJ1QRK8SBnc'},
#    'followers': {'href': None, 'total': 1907737},
#    'genres': ['british singer-songwriter',
#     'folk-pop',
#     'indie folk',
#     'neo mellow',
#     'pop rock',
#     'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/5schNIzWdI9gJ1QRK8SBnc',
#    'id': '5schNIzWdI9gJ1QRK8SBnc',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb7f6d3ce714aba5b2c38212dc',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051747f6d3ce714aba5b2c38212dc',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1787f6d3ce714aba5b2c38212dc',
#      'width': 160}],
#    'name': 'Ben Howard',
#    'popularity': 69,
#    'type': 'artist',
#    'uri': 'spotify:artist:5schNIzWdI9gJ1QRK8SBnc'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5schNIzWdI9gJ1QRK8SBnc'},
#    'followers': {'href': None, 'total': 1907737},
#    'genres': ['british singer-songwriter',
#     'folk-pop',
#     'indie folk',
#     'neo mellow',
#     'pop rock',
#     'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/5schNIzWdI9gJ1QRK8SBnc',
#    'id': '5schNIzWdI9gJ1QRK8SBnc',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb7f6d3ce714aba5b2c38212dc',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051747f6d3ce714aba5b2c38212dc',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1787f6d3ce714aba5b2c38212dc',
#      'width': 160}],
#    'name': 'Ben Howard',
#    'popularity': 69,
#    'type': 'artist',
#    'uri': 'spotify:artist:5schNIzWdI9gJ1QRK8SBnc'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0mXTJETA4XUa12MmmXxZJh'},
#    'followers': {'href': None, 'total': 1285944},
#    'genres': ['acoustic rock', 'permanent wave'],
#    'href': 'https://api.spotify.com/v1/artists/0mXTJETA4XUa12MmmXxZJh',
#    'id': '0mXTJETA4XUa12MmmXxZJh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb98a58862098f8be6496ba9d6',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517498a58862098f8be6496ba9d6',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17898a58862098f8be6496ba9d6',
#      'width': 160}],
#    'name': 'Eddie Vedder',
#    'popularity': 66,
#    'type': 'artist',
#    'uri': 'spotify:artist:0mXTJETA4XUa12MmmXxZJh'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5BvJzeQpmsdsFp4HGUYUEx'},
#    'followers': {'href': None, 'total': 1750771},
#    'genres': ['baroque pop', 'indie rock', 'modern rock'],
#    'href': 'https://api.spotify.com/v1/artists/5BvJzeQpmsdsFp4HGUYUEx',
#    'id': '5BvJzeQpmsdsFp4HGUYUEx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb44829ac83c4538a8cf7e9f40',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517444829ac83c4538a8cf7e9f40',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17844829ac83c4538a8cf7e9f40',
#      'width': 160}],
#    'name': 'Vampire Weekend',
#    'popularity': 69,
#    'type': 'artist',
#    'uri': 'spotify:artist:5BvJzeQpmsdsFp4HGUYUEx'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/14r9dR01KeBLFfylVSKCZQ'},
#    'followers': {'href': None, 'total': 965946},
#    'genres': ['acoustic pop',
#     'irish rock',
#     'irish singer-songwriter',
#     'neo mellow',
#     'singer-songwriter'],
#    'href': 'https://api.spotify.com/v1/artists/14r9dR01KeBLFfylVSKCZQ',
#    'id': '14r9dR01KeBLFfylVSKCZQ',
#    'images': [{'height': 1409,
#      'url': 'https://i.scdn.co/image/2e30a95ed5539cc08cc339439a596db30304d31a',
#      'width': 1000},
#     {'height': 902,
#      'url': 'https://i.scdn.co/image/e8e6da146e50f6ecf637a59be3ec5ca5a8b2c89c',
#      'width': 640},
#     {'height': 282,
#      'url': 'https://i.scdn.co/image/7b2cde62c87ceb07859b16e4e9f5cd97d82c36d3',
#      'width': 200},
#     {'height': 90,
#      'url': 'https://i.scdn.co/image/9e4aff40a033eb55197826d5786cc219930276f6',
#      'width': 64}],
#    'name': 'Damien Rice',
#    'popularity': 63,
#    'type': 'artist',
#    'uri': 'spotify:artist:14r9dR01KeBLFfylVSKCZQ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4MXUO7sVCaFgFjoTI5ox5c'},
#    'followers': {'href': None, 'total': 1388411},
#    'genres': ['baroque pop',
#     'chamber pop',
#     'freak folk',
#     'indie folk',
#     'singer-songwriter'],
#    'href': 'https://api.spotify.com/v1/artists/4MXUO7sVCaFgFjoTI5ox5c',
#    'id': '4MXUO7sVCaFgFjoTI5ox5c',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb6bb28451de514ef1f3c5bf30',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051746bb28451de514ef1f3c5bf30',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1786bb28451de514ef1f3c5bf30',
#      'width': 160}],
#    'name': 'Sufjan Stevens',
#    'popularity': 72,
#    'type': 'artist',
#    'uri': 'spotify:artist:4MXUO7sVCaFgFjoTI5ox5c'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6pmxr66tMAePxzOLfjGNcX'},
#    'followers': {'href': None, 'total': 879303},
#    'genres': ['albuquerque indie',
#     'baroque pop',
#     'chamber pop',
#     'indie pop',
#     'indie rock',
#     'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/6pmxr66tMAePxzOLfjGNcX',
#    'id': '6pmxr66tMAePxzOLfjGNcX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebe58e75796ce15b2703a901db',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174e58e75796ce15b2703a901db',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178e58e75796ce15b2703a901db',
#      'width': 160}],
#    'name': 'Beirut',
#    'popularity': 59,
#    'type': 'artist',
#    'uri': 'spotify:artist:6pmxr66tMAePxzOLfjGNcX'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/63MQldklfxkjYDoUE4Tppz'},
#    'followers': {'href': None, 'total': 1956205},
#    'genres': ['french shoegaze',
#     'french synthpop',
#     'indietronica',
#     'metropopolis',
#     'neo-synthpop'],
#    'href': 'https://api.spotify.com/v1/artists/63MQldklfxkjYDoUE4Tppz',
#    'id': '63MQldklfxkjYDoUE4Tppz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eba1d522250f406d83889a26f3',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174a1d522250f406d83889a26f3',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178a1d522250f406d83889a26f3',
#      'width': 160}],
#    'name': 'M83',
#    'popularity': 71,
#    'type': 'artist',
#    'uri': 'spotify:artist:63MQldklfxkjYDoUE4Tppz'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/63MQldklfxkjYDoUE4Tppz'},
#    'followers': {'href': None, 'total': 1956205},
#    'genres': ['french shoegaze',
#     'french synthpop',
#     'indietronica',
#     'metropopolis',
#     'neo-synthpop'],
#    'href': 'https://api.spotify.com/v1/artists/63MQldklfxkjYDoUE4Tppz',
#    'id': '63MQldklfxkjYDoUE4Tppz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eba1d522250f406d83889a26f3',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174a1d522250f406d83889a26f3',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178a1d522250f406d83889a26f3',
#      'width': 160}],
#    'name': 'M83',
#    'popularity': 71,
#    'type': 'artist',
#    'uri': 'spotify:artist:63MQldklfxkjYDoUE4Tppz'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa'},
#    'followers': {'href': None, 'total': 14113105},
#    'genres': ['art pop', 'pop'],
#    'href': 'https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa',
#    'id': '00FQb4jTyendYWaN8pK0wa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebc5903678d3db18e271e42be0',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174c5903678d3db18e271e42be0',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178c5903678d3db18e271e42be0',
#      'width': 160}],
#    'name': 'Lana Del Rey',
#    'popularity': 85,
#    'type': 'artist',
#    'uri': 'spotify:artist:00FQb4jTyendYWaN8pK0wa'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gP3bB2nilZXLfPHJhMdvc'},
#    'followers': {'href': None, 'total': 3267426},
#    'genres': ['indietronica',
#     'modern alternative rock',
#     'modern rock',
#     'pop rock',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/7gP3bB2nilZXLfPHJhMdvc',
#    'id': '7gP3bB2nilZXLfPHJhMdvc',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb562494fff8e756a27bc7a6d2',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174562494fff8e756a27bc7a6d2',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178562494fff8e756a27bc7a6d2',
#      'width': 160}],
#    'name': 'Foster The People',
#    'popularity': 75,
#    'type': 'artist',
#    'uri': 'spotify:artist:7gP3bB2nilZXLfPHJhMdvc'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7G1GBhoKtEPnP86X2PvEYO'},
#    'followers': {'href': None, 'total': 2290600},
#    'genres': ['jazz blues', 'soul', 'soul jazz', 'torch song', 'vocal jazz'],
#    'href': 'https://api.spotify.com/v1/artists/7G1GBhoKtEPnP86X2PvEYO',
#    'id': '7G1GBhoKtEPnP86X2PvEYO',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb136c51c848c26a6cce7f9e56',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174136c51c848c26a6cce7f9e56',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178136c51c848c26a6cce7f9e56',
#      'width': 160}],
#    'name': 'Nina Simone',
#    'popularity': 71,
#    'type': 'artist',
#    'uri': 'spotify:artist:7G1GBhoKtEPnP86X2PvEYO'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5I4eibDkC7gg0hmczTZuND'},
#    'followers': {'href': None, 'total': 271019},
#    'genres': ['dalarna indie', 'swedish garage rock', 'swedish indie rock'],
#    'href': 'https://api.spotify.com/v1/artists/5I4eibDkC7gg0hmczTZuND',
#    'id': '5I4eibDkC7gg0hmczTZuND',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb73428e4db4c578bda516a32c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517473428e4db4c578bda516a32c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17873428e4db4c578bda516a32c',
#      'width': 160}],
#    'name': 'Mando Diao',
#    'popularity': 58,
#    'type': 'artist',
#    'uri': 'spotify:artist:5I4eibDkC7gg0hmczTZuND'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#    'followers': {'href': None, 'total': 12698277},
#    'genres': ['garage rock', 'permanent wave', 'rock', 'sheffield indie'],
#    'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#    'id': '7Ln80lUS6He07XvHI8qqHH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb39f37a34b404169fdca52dc8',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517439f37a34b404169fdca52dc8',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17839f37a34b404169fdca52dc8',
#      'width': 160}],
#    'name': 'Arctic Monkeys',
#    'popularity': 84,
#    'type': 'artist',
#    'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/11wRdbnoYqRddKBrpHt4Ue'},
#    'followers': {'href': None, 'total': 1585235},
#    'genres': ['alternative rock',
#     'britpop',
#     'garage rock',
#     'indie rock',
#     'leicester indie',
#     'modern rock',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/11wRdbnoYqRddKBrpHt4Ue',
#    'id': '11wRdbnoYqRddKBrpHt4Ue',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebb58f3e5f0a9b8afcb1c5c15e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174b58f3e5f0a9b8afcb1c5c15e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178b58f3e5f0a9b8afcb1c5c15e',
#      'width': 160}],
#    'name': 'Kasabian',
#    'popularity': 64,
#    'type': 'artist',
#    'uri': 'spotify:artist:11wRdbnoYqRddKBrpHt4Ue'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/11wRdbnoYqRddKBrpHt4Ue'},
#    'followers': {'href': None, 'total': 1585235},
#    'genres': ['alternative rock',
#     'britpop',
#     'garage rock',
#     'indie rock',
#     'leicester indie',
#     'modern rock',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/11wRdbnoYqRddKBrpHt4Ue',
#    'id': '11wRdbnoYqRddKBrpHt4Ue',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebb58f3e5f0a9b8afcb1c5c15e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174b58f3e5f0a9b8afcb1c5c15e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178b58f3e5f0a9b8afcb1c5c15e',
#      'width': 160}],
#    'name': 'Kasabian',
#    'popularity': 64,
#    'type': 'artist',
#    'uri': 'spotify:artist:11wRdbnoYqRddKBrpHt4Ue'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#    'followers': {'href': None, 'total': 1504269},
#    'genres': ['alternative rock',
#     'britpop',
#     'modern rock',
#     'permanent wave',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#    'id': '6RZUqkomCmb8zCRqc9eznB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eba52698d28f9517190e752b52',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174a52698d28f9517190e752b52',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178a52698d28f9517190e752b52',
#      'width': 160}],
#    'name': 'Placebo',
#    'popularity': 68,
#    'type': 'artist',
#    'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6UUrUCIZtQeOf8tC0WuzRy'},
#    'followers': {'href': None, 'total': 1085285},
#    'genres': ['compositional ambient',
#     'dream pop',
#     'ethereal wave',
#     'icelandic rock',
#     'melancholia',
#     'nordic post-rock',
#     'post-rock'],
#    'href': 'https://api.spotify.com/v1/artists/6UUrUCIZtQeOf8tC0WuzRy',
#    'id': '6UUrUCIZtQeOf8tC0WuzRy',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb19d0792023e59a8dda1dc716',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517419d0792023e59a8dda1dc716',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17819d0792023e59a8dda1dc716',
#      'width': 160}],
#    'name': 'Sigur Rós',
#    'popularity': 58,
#    'type': 'artist',
#    'uri': 'spotify:artist:6UUrUCIZtQeOf8tC0WuzRy'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6urkHDoIVO1WO8vNIwcJmM'},
#    'followers': {'href': None, 'total': 1515590},
#    'genres': ['african rock',
#     'south african alternative',
#     'south african hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/6urkHDoIVO1WO8vNIwcJmM',
#    'id': '6urkHDoIVO1WO8vNIwcJmM',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb2eac7f5f26448433ef465116',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051742eac7f5f26448433ef465116',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1782eac7f5f26448433ef465116',
#      'width': 160}],
#    'name': 'Die Antwoord',
#    'popularity': 62,
#    'type': 'artist',
#    'uri': 'spotify:artist:6urkHDoIVO1WO8vNIwcJmM'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6urkHDoIVO1WO8vNIwcJmM'},
#    'followers': {'href': None, 'total': 1515590},
#    'genres': ['african rock',
#     'south african alternative',
#     'south african hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/6urkHDoIVO1WO8vNIwcJmM',
#    'id': '6urkHDoIVO1WO8vNIwcJmM',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb2eac7f5f26448433ef465116',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051742eac7f5f26448433ef465116',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1782eac7f5f26448433ef465116',
#      'width': 160}],
#    'name': 'Die Antwoord',
#    'popularity': 62,
#    'type': 'artist',
#    'uri': 'spotify:artist:6urkHDoIVO1WO8vNIwcJmM'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5I4eibDkC7gg0hmczTZuND'},
#    'followers': {'href': None, 'total': 271019},
#    'genres': ['dalarna indie', 'swedish garage rock', 'swedish indie rock'],
#    'href': 'https://api.spotify.com/v1/artists/5I4eibDkC7gg0hmczTZuND',
#    'id': '5I4eibDkC7gg0hmczTZuND',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb73428e4db4c578bda516a32c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517473428e4db4c578bda516a32c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17873428e4db4c578bda516a32c',
#      'width': 160}],
#    'name': 'Mando Diao',
#    'popularity': 58,
#    'type': 'artist',
#    'uri': 'spotify:artist:5I4eibDkC7gg0hmczTZuND'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#    'followers': {'href': None, 'total': 6651161},
#    'genres': ['modern rock', 'permanent wave', 'rock'],
#    'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#    'id': '12Chz98pHFMPJEknJQMWvI',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebb506164c3174bb7123a41424',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174b506164c3174bb7123a41424',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178b506164c3174bb7123a41424',
#      'width': 160}],
#    'name': 'Muse',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#    'followers': {'href': None, 'total': 7426092},
#    'genres': ['british soul', 'indie r&b', 'neo soul'],
#    'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#    'id': '6Q192DXotxtaysaqNPy5yR',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb2ceb023b10da17590878e88c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051742ceb023b10da17590878e88c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1782ceb023b10da17590878e88c',
#      'width': 160}],
#    'name': 'Amy Winehouse',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IAZ2xX1Ovh5jxhBWE7wda'},
#    'followers': {'href': None, 'total': 338556},
#    'genres': ['neo mellow', 'pop rock'],
#    'href': 'https://api.spotify.com/v1/artists/2IAZ2xX1Ovh5jxhBWE7wda',
#    'id': '2IAZ2xX1Ovh5jxhBWE7wda',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb39566ca17a6bac6445e93cf0',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517439566ca17a6bac6445e93cf0',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17839566ca17a6bac6445e93cf0',
#      'width': 160}],
#    'name': 'Donavon Frankenreiter',
#    'popularity': 60,
#    'type': 'artist',
#    'uri': 'spotify:artist:2IAZ2xX1Ovh5jxhBWE7wda'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6CQrZZn0g2ZNfIcXbi4pdo'},
#    'followers': {'href': None, 'total': 57884},
#    'genres': ['deep new americana', 'indie folk', 'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/6CQrZZn0g2ZNfIcXbi4pdo',
#    'id': '6CQrZZn0g2ZNfIcXbi4pdo',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb5aa5e66436970acfeacf9b8d',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051745aa5e66436970acfeacf9b8d',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1785aa5e66436970acfeacf9b8d',
#      'width': 160}],
#    'name': 'Mason Jennings',
#    'popularity': 44,
#    'type': 'artist',
#    'uri': 'spotify:artist:6CQrZZn0g2ZNfIcXbi4pdo'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/75EZuo5MHV2572NRpMWotC'},
#    'followers': {'href': None, 'total': 341970},
#    'genres': ['alternative dance', 'new rave'],
#    'href': 'https://api.spotify.com/v1/artists/75EZuo5MHV2572NRpMWotC',
#    'id': '75EZuo5MHV2572NRpMWotC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb9d13d6f4a3f1f2686703fc6e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051749d13d6f4a3f1f2686703fc6e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1789d13d6f4a3f1f2686703fc6e',
#      'width': 160}],
#    'name': 'Crystal Fighters',
#    'popularity': 54,
#    'type': 'artist',
#    'uri': 'spotify:artist:75EZuo5MHV2572NRpMWotC'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Z7gV3uEh1ckIaBzTUCE6R'},
#    'followers': {'href': None, 'total': 141322},
#    'genres': ['indie folk',
#     'indie pop',
#     'indie rock',
#     'melancholia',
#     'omaha indie',
#     'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/2Z7gV3uEh1ckIaBzTUCE6R',
#    'id': '2Z7gV3uEh1ckIaBzTUCE6R',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebdb1521ee291c16725c9042c7',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174db1521ee291c16725c9042c7',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178db1521ee291c16725c9042c7',
#      'width': 160}],
#    'name': 'Conor Oberst',
#    'popularity': 53,
#    'type': 'artist',
#    'uri': 'spotify:artist:2Z7gV3uEh1ckIaBzTUCE6R'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4M5nCE77Qaxayuhp3fVn4V'},
#    'followers': {'href': None, 'total': 977066},
#    'genres': ['indie folk', 'indie pop', 'neo mellow', 'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/4M5nCE77Qaxayuhp3fVn4V',
#    'id': '4M5nCE77Qaxayuhp3fVn4V',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb372f49de83296ace5496e1ac',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174372f49de83296ace5496e1ac',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178372f49de83296ace5496e1ac',
#      'width': 160}],
#    'name': 'Iron & Wine',
#    'popularity': 66,
#    'type': 'artist',
#    'uri': 'spotify:artist:4M5nCE77Qaxayuhp3fVn4V'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/05TeWWFqSVEUurt1lVhh4q'},
#    'followers': {'href': None, 'total': 68129},
#    'genres': ['french indie pop'],
#    'href': 'https://api.spotify.com/v1/artists/05TeWWFqSVEUurt1lVhh4q',
#    'id': '05TeWWFqSVEUurt1lVhh4q',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb3a36c007495c391114552420',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051743a36c007495c391114552420',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1783a36c007495c391114552420',
#      'width': 160}],
#    'name': 'Lou Doillon',
#    'popularity': 47,
#    'type': 'artist',
#    'uri': 'spotify:artist:05TeWWFqSVEUurt1lVhh4q'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/44NX2ffIYHr6D4n7RaZF7A'},
#    'followers': {'href': None, 'total': 2221788},
#    'genres': ['classic rock',
#     'folk',
#     'folk rock',
#     'mellow gold',
#     'rock',
#     'roots rock',
#     'singer-songwriter',
#     'soft rock'],
#    'href': 'https://api.spotify.com/v1/artists/44NX2ffIYHr6D4n7RaZF7A',
#    'id': '44NX2ffIYHr6D4n7RaZF7A',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebb30dfdb5154628feb5e46041',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174b30dfdb5154628feb5e46041',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178b30dfdb5154628feb5e46041',
#      'width': 160}],
#    'name': 'Van Morrison',
#    'popularity': 74,
#    'type': 'artist',
#    'uri': 'spotify:artist:44NX2ffIYHr6D4n7RaZF7A'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/79JJCxCCfJ8HufX6w8q2k4'},
#    'followers': {'href': None, 'total': 154547},
#    'genres': ['alternative country',
#     'chamber pop',
#     'freak folk',
#     'indie folk',
#     'indie pop',
#     'indie rock',
#     'new americana',
#     'stomp and holler'],
#    'href': 'https://api.spotify.com/v1/artists/79JJCxCCfJ8HufX6w8q2k4',
#    'id': '79JJCxCCfJ8HufX6w8q2k4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb60e6bb4c4d216f1d3df0c1d3',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab6761610000517460e6bb4c4d216f1d3df0c1d3',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f17860e6bb4c4d216f1d3df0c1d3',
#      'width': 160}],
#    'name': 'Damien Jurado',
#    'popularity': 55,
#    'type': 'artist',
#    'uri': 'spotify:artist:79JJCxCCfJ8HufX6w8q2k4'}]}

# %%
#put dictionaries back together
first_50_artists = first_50['artists']
second_50_artists = second_50['artists']

all_100_artists = first_50_artists + second_50_artists
all_100_artists
#len(all_100_artists)
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#   'followers': {'href': None, 'total': 6445637},
#   'genres': ['alternative rock',
#    'art rock',
#    'melancholia',
#    'oxford indie',
#    'permanent wave',
#    'rock'],
#   'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#   'id': '4Z8W4fKeB5YxbusRsdQVPb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eba03696716c9ee605006047fd',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174a03696716c9ee605006047fd',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178a03696716c9ee605006047fd',
#     'width': 160}],
#   'name': 'Radiohead',
#   'popularity': 79,
#   'type': 'artist',
#   'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#   'followers': {'href': None, 'total': 745663},
#   'genres': ['art pop',
#    'electronica',
#    'glitch pop',
#    'indie rock',
#    'oxford indie'],
#   'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#   'id': '4CvTDPKA6W06DRfBnZKrau',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb3153f6fe26063cfcbfc57677',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051743153f6fe26063cfcbfc57677',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1783153f6fe26063cfcbfc57677',
#     'width': 160}],
#   'name': 'Thom Yorke',
#   'popularity': 61,
#   'type': 'artist',
#   'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Eu1txygG6nJttLHbZdQOh'},
#   'followers': {'href': None, 'total': 549069},
#   'genres': ['alternative dance',
#    'electronica',
#    'folktronica',
#    'intelligent dance music',
#    'new rave'],
#   'href': 'https://api.spotify.com/v1/artists/7Eu1txygG6nJttLHbZdQOh',
#   'id': '7Eu1txygG6nJttLHbZdQOh',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb84e29d09b4917bec2700a0d7',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517484e29d09b4917bec2700a0d7',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17884e29d09b4917bec2700a0d7',
#     'width': 160}],
#   'name': 'Four Tet',
#   'popularity': 62,
#   'type': 'artist',
#   'uri': 'spotify:artist:7Eu1txygG6nJttLHbZdQOh'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#   'followers': {'href': None, 'total': 6445637},
#   'genres': ['alternative rock',
#    'art rock',
#    'melancholia',
#    'oxford indie',
#    'permanent wave',
#    'rock'],
#   'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#   'id': '4Z8W4fKeB5YxbusRsdQVPb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eba03696716c9ee605006047fd',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174a03696716c9ee605006047fd',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178a03696716c9ee605006047fd',
#     'width': 160}],
#   'name': 'Radiohead',
#   'popularity': 79,
#   'type': 'artist',
#   'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#   'followers': {'href': None, 'total': 6445637},
#   'genres': ['alternative rock',
#    'art rock',
#    'melancholia',
#    'oxford indie',
#    'permanent wave',
#    'rock'],
#   'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#   'id': '4Z8W4fKeB5YxbusRsdQVPb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eba03696716c9ee605006047fd',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174a03696716c9ee605006047fd',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178a03696716c9ee605006047fd',
#     'width': 160}],
#   'name': 'Radiohead',
#   'popularity': 79,
#   'type': 'artist',
#   'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6liAMWkVf5LH7YR9yfFy1Y'},
#   'followers': {'href': None, 'total': 1473368},
#   'genres': ['electronica', 'laboratorio', 'trip hop'],
#   'href': 'https://api.spotify.com/v1/artists/6liAMWkVf5LH7YR9yfFy1Y',
#   'id': '6liAMWkVf5LH7YR9yfFy1Y',
#   'images': [{'height': 680,
#     'url': 'https://i.scdn.co/image/05d3721739aee511a898081ab140daa7890a0120',
#     'width': 1000},
#    {'height': 435,
#     'url': 'https://i.scdn.co/image/27802710b01453435de93d71bab2c9988a841ace',
#     'width': 640},
#    {'height': 136,
#     'url': 'https://i.scdn.co/image/333ac38e3c8ab5fcdc238cc46535a4abb802eccc',
#     'width': 200},
#    {'height': 44,
#     'url': 'https://i.scdn.co/image/10052054c06626f6a900e687b20886e462f75568',
#     'width': 64}],
#   'name': 'Portishead',
#   'popularity': 62,
#   'type': 'artist',
#   'uri': 'spotify:artist:6liAMWkVf5LH7YR9yfFy1Y'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6liAMWkVf5LH7YR9yfFy1Y'},
#   'followers': {'href': None, 'total': 1473368},
#   'genres': ['electronica', 'laboratorio', 'trip hop'],
#   'href': 'https://api.spotify.com/v1/artists/6liAMWkVf5LH7YR9yfFy1Y',
#   'id': '6liAMWkVf5LH7YR9yfFy1Y',
#   'images': [{'height': 680,
#     'url': 'https://i.scdn.co/image/05d3721739aee511a898081ab140daa7890a0120',
#     'width': 1000},
#    {'height': 435,
#     'url': 'https://i.scdn.co/image/27802710b01453435de93d71bab2c9988a841ace',
#     'width': 640},
#    {'height': 136,
#     'url': 'https://i.scdn.co/image/333ac38e3c8ab5fcdc238cc46535a4abb802eccc',
#     'width': 200},
#    {'height': 44,
#     'url': 'https://i.scdn.co/image/10052054c06626f6a900e687b20886e462f75568',
#     'width': 64}],
#   'name': 'Portishead',
#   'popularity': 62,
#   'type': 'artist',
#   'uri': 'spotify:artist:6liAMWkVf5LH7YR9yfFy1Y'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6FXMGgJwohJLUSr5nVlf9X'},
#   'followers': {'href': None, 'total': 1752572},
#   'genres': ['big beat', 'downtempo', 'electronica', 'trip hop'],
#   'href': 'https://api.spotify.com/v1/artists/6FXMGgJwohJLUSr5nVlf9X',
#   'id': '6FXMGgJwohJLUSr5nVlf9X',
#   'images': [{'height': 1335,
#     'url': 'https://i.scdn.co/image/c8bbeedb05f38ae5cb982a7daf4bf7129cca892c',
#     'width': 1000},
#    {'height': 855,
#     'url': 'https://i.scdn.co/image/52c2a824e84f4e8adf0b12418f9f8306b4b5b77a',
#     'width': 640},
#    {'height': 267,
#     'url': 'https://i.scdn.co/image/0d6b7677f8291c5158bdace8a6e027880c527c2a',
#     'width': 200},
#    {'height': 85,
#     'url': 'https://i.scdn.co/image/c055290bb6e97a589d8ca659cd452a8e9831c2c4',
#     'width': 64}],
#   'name': 'Massive Attack',
#   'popularity': 66,
#   'type': 'artist',
#   'uri': 'spotify:artist:6FXMGgJwohJLUSr5nVlf9X'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6FXMGgJwohJLUSr5nVlf9X'},
#   'followers': {'href': None, 'total': 1752572},
#   'genres': ['big beat', 'downtempo', 'electronica', 'trip hop'],
#   'href': 'https://api.spotify.com/v1/artists/6FXMGgJwohJLUSr5nVlf9X',
#   'id': '6FXMGgJwohJLUSr5nVlf9X',
#   'images': [{'height': 1335,
#     'url': 'https://i.scdn.co/image/c8bbeedb05f38ae5cb982a7daf4bf7129cca892c',
#     'width': 1000},
#    {'height': 855,
#     'url': 'https://i.scdn.co/image/52c2a824e84f4e8adf0b12418f9f8306b4b5b77a',
#     'width': 640},
#    {'height': 267,
#     'url': 'https://i.scdn.co/image/0d6b7677f8291c5158bdace8a6e027880c527c2a',
#     'width': 200},
#    {'height': 85,
#     'url': 'https://i.scdn.co/image/c055290bb6e97a589d8ca659cd452a8e9831c2c4',
#     'width': 64}],
#   'name': 'Massive Attack',
#   'popularity': 66,
#   'type': 'artist',
#   'uri': 'spotify:artist:6FXMGgJwohJLUSr5nVlf9X'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5nPOO9iTcrs9k6yFffPxjH'},
#   'followers': {'href': None, 'total': 737470},
#   'genres': ['alternative dance',
#    'big beat',
#    'downtempo',
#    'electronica',
#    'electropop',
#    'new rave',
#    'trip hop'],
#   'href': 'https://api.spotify.com/v1/artists/5nPOO9iTcrs9k6yFffPxjH',
#   'id': '5nPOO9iTcrs9k6yFffPxjH',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebbfecf14daf2c1bc11c7b163b',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174bfecf14daf2c1bc11c7b163b',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178bfecf14daf2c1bc11c7b163b',
#     'width': 160}],
#   'name': 'Röyksopp',
#   'popularity': 61,
#   'type': 'artist',
#   'uri': 'spotify:artist:5nPOO9iTcrs9k6yFffPxjH'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4O71i7ke5iIBX6RNSFoZbS'},
#   'followers': {'href': None, 'total': 326116},
#   'genres': ['alternative dance',
#    'danish electronic',
#    'danish electropop',
#    'electronica',
#    'microhouse',
#    'minimal techno',
#    'trip hop'],
#   'href': 'https://api.spotify.com/v1/artists/4O71i7ke5iIBX6RNSFoZbS',
#   'id': '4O71i7ke5iIBX6RNSFoZbS',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb658cefaac50d0d0d4e3b88f3',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174658cefaac50d0d0d4e3b88f3',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178658cefaac50d0d0d4e3b88f3',
#     'width': 160}],
#   'name': 'trentemøller',
#   'popularity': 52,
#   'type': 'artist',
#   'uri': 'spotify:artist:4O71i7ke5iIBX6RNSFoZbS'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2mcNCn1qbZUQ3J9KHapUxj'},
#   'followers': {'href': None, 'total': 312308},
#   'genres': ['french indie pop',
#    'french indietronica',
#    'french rock',
#    'rock independant francais'],
#   'href': 'https://api.spotify.com/v1/artists/2mcNCn1qbZUQ3J9KHapUxj',
#   'id': '2mcNCn1qbZUQ3J9KHapUxj',
#   'images': [{'height': 777,
#     'url': 'https://i.scdn.co/image/cec237756f0fccb3a0c2abe8ed0ac3d7278b646e',
#     'width': 776},
#    {'height': 641,
#     'url': 'https://i.scdn.co/image/0d94f0d43132aa9762a9958e4eba50c049d956ce',
#     'width': 640},
#    {'height': 200,
#     'url': 'https://i.scdn.co/image/14b80a920ea2eada46ea9124ee994fa68c43d641',
#     'width': 200},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/a26d11afd58fc9ab582e7f2001a592023a192c34',
#     'width': 64}],
#   'name': 'The Dø',
#   'popularity': 52,
#   'type': 'artist',
#   'uri': 'spotify:artist:2mcNCn1qbZUQ3J9KHapUxj'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2exkZbmNqMKnT8LRWuxWgy'},
#   'followers': {'href': None, 'total': 562053},
#   'genres': ['alternative dance', 'electronica', 'minimal techno', 'new rave'],
#   'href': 'https://api.spotify.com/v1/artists/2exkZbmNqMKnT8LRWuxWgy',
#   'id': '2exkZbmNqMKnT8LRWuxWgy',
#   'images': [{'height': 1000,
#     'url': 'https://i.scdn.co/image/aa28d008f92636cfd4088461e39b783f57eeb0c6',
#     'width': 1000},
#    {'height': 640,
#     'url': 'https://i.scdn.co/image/04a1d0d490d700b1a6feeacd31db5e5bfe1bc737',
#     'width': 640},
#    {'height': 200,
#     'url': 'https://i.scdn.co/image/1d7996e31fb7783c403516db8bd96c5183d29d63',
#     'width': 200},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/e78f4e41879d04b780f6c580c59fab4143f3ebb0',
#     'width': 64}],
#   'name': 'Moderat',
#   'popularity': 57,
#   'type': 'artist',
#   'uri': 'spotify:artist:2exkZbmNqMKnT8LRWuxWgy'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2exkZbmNqMKnT8LRWuxWgy'},
#   'followers': {'href': None, 'total': 562053},
#   'genres': ['alternative dance', 'electronica', 'minimal techno', 'new rave'],
#   'href': 'https://api.spotify.com/v1/artists/2exkZbmNqMKnT8LRWuxWgy',
#   'id': '2exkZbmNqMKnT8LRWuxWgy',
#   'images': [{'height': 1000,
#     'url': 'https://i.scdn.co/image/aa28d008f92636cfd4088461e39b783f57eeb0c6',
#     'width': 1000},
#    {'height': 640,
#     'url': 'https://i.scdn.co/image/04a1d0d490d700b1a6feeacd31db5e5bfe1bc737',
#     'width': 640},
#    {'height': 200,
#     'url': 'https://i.scdn.co/image/1d7996e31fb7783c403516db8bd96c5183d29d63',
#     'width': 200},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/e78f4e41879d04b780f6c580c59fab4143f3ebb0',
#     'width': 64}],
#   'name': 'Moderat',
#   'popularity': 57,
#   'type': 'artist',
#   'uri': 'spotify:artist:2exkZbmNqMKnT8LRWuxWgy'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#   'followers': {'href': None, 'total': 31951841},
#   'genres': ['permanent wave', 'pop'],
#   'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#   'id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb865a3301762a8fce048cb469',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174865a3301762a8fce048cb469',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178865a3301762a8fce048cb469',
#     'width': 160}],
#   'name': 'Coldplay',
#   'popularity': 89,
#   'type': 'artist',
#   'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#   'followers': {'href': None, 'total': 31951841},
#   'genres': ['permanent wave', 'pop'],
#   'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#   'id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb865a3301762a8fce048cb469',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174865a3301762a8fce048cb469',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178865a3301762a8fce048cb469',
#     'width': 160}],
#   'name': 'Coldplay',
#   'popularity': 89,
#   'type': 'artist',
#   'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#   'followers': {'href': None, 'total': 32104887},
#   'genres': ['brostep',
#    'edm',
#    'pop',
#    'pop dance',
#    'progressive electro house'],
#   'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#   'id': '64KEffDW9EtZ1y2vBYgq8T',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eba91af711541f8807ed7f0676',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174a91af711541f8807ed7f0676',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178a91af711541f8807ed7f0676',
#     'width': 160}],
#   'name': 'Marshmello',
#   'popularity': 86,
#   'type': 'artist',
#   'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2DaxqgrOhkeH0fpeiQq2f4'},
#   'followers': {'href': None, 'total': 6630543},
#   'genres': ['beatlesque', 'britpop', 'madchester', 'permanent wave', 'rock'],
#   'href': 'https://api.spotify.com/v1/artists/2DaxqgrOhkeH0fpeiQq2f4',
#   'id': '2DaxqgrOhkeH0fpeiQq2f4',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb89aff1367f1c02cfe17dd0b3',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517489aff1367f1c02cfe17dd0b3',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17889aff1367f1c02cfe17dd0b3',
#     'width': 160}],
#   'name': 'Oasis',
#   'popularity': 78,
#   'type': 'artist',
#   'uri': 'spotify:artist:2DaxqgrOhkeH0fpeiQq2f4'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#   'followers': {'href': None, 'total': 10814125},
#   'genres': ['british invasion', 'classic rock', 'rock'],
#   'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#   'id': '22bE4uQ6baNwSHPVcDxLCe',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebd3cb15a8570cce5a63af63d8',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174d3cb15a8570cce5a63af63d8',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178d3cb15a8570cce5a63af63d8',
#     'width': 160}],
#   'name': 'The Rolling Stones',
#   'popularity': 81,
#   'type': 'artist',
#   'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#   'followers': {'href': None, 'total': 10814125},
#   'genres': ['british invasion', 'classic rock', 'rock'],
#   'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#   'id': '22bE4uQ6baNwSHPVcDxLCe',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebd3cb15a8570cce5a63af63d8',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174d3cb15a8570cce5a63af63d8',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178d3cb15a8570cce5a63af63d8',
#     'width': 160}],
#   'name': 'The Rolling Stones',
#   'popularity': 81,
#   'type': 'artist',
#   'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#   'followers': {'href': None, 'total': 10814125},
#   'genres': ['british invasion', 'classic rock', 'rock'],
#   'href': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe',
#   'id': '22bE4uQ6baNwSHPVcDxLCe',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebd3cb15a8570cce5a63af63d8',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174d3cb15a8570cce5a63af63d8',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178d3cb15a8570cce5a63af63d8',
#     'width': 160}],
#   'name': 'The Rolling Stones',
#   'popularity': 81,
#   'type': 'artist',
#   'uri': 'spotify:artist:22bE4uQ6baNwSHPVcDxLCe'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/776Uo845nYHJpNaStv1Ds4'},
#   'followers': {'href': None, 'total': 5192909},
#   'genres': ['acid rock',
#    'album rock',
#    'blues rock',
#    'classic rock',
#    'hard rock',
#    'psychedelic rock',
#    'rock'],
#   'href': 'https://api.spotify.com/v1/artists/776Uo845nYHJpNaStv1Ds4',
#   'id': '776Uo845nYHJpNaStv1Ds4',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb31f6ab67e6025de876475814',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517431f6ab67e6025de876475814',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17831f6ab67e6025de876475814',
#     'width': 160}],
#   'name': 'Jimi Hendrix',
#   'popularity': 73,
#   'type': 'artist',
#   'uri': 'spotify:artist:776Uo845nYHJpNaStv1Ds4'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/776Uo845nYHJpNaStv1Ds4'},
#   'followers': {'href': None, 'total': 5192909},
#   'genres': ['acid rock',
#    'album rock',
#    'blues rock',
#    'classic rock',
#    'hard rock',
#    'psychedelic rock',
#    'rock'],
#   'href': 'https://api.spotify.com/v1/artists/776Uo845nYHJpNaStv1Ds4',
#   'id': '776Uo845nYHJpNaStv1Ds4',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb31f6ab67e6025de876475814',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517431f6ab67e6025de876475814',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17831f6ab67e6025de876475814',
#     'width': 160}],
#   'name': 'Jimi Hendrix',
#   'popularity': 73,
#   'type': 'artist',
#   'uri': 'spotify:artist:776Uo845nYHJpNaStv1Ds4'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4vpDg7Y7fU982Ds30zawDA'},
#   'followers': {'href': None, 'total': 823890},
#   'genres': ['album rock',
#    'blues rock',
#    'classic canadian rock',
#    'classic rock',
#    'cosmic american',
#    'country rock',
#    'folk',
#    'folk rock',
#    'heartland rock',
#    'jam band',
#    'mellow gold',
#    'rock',
#    'roots rock',
#    'soft rock',
#    'swamp rock'],
#   'href': 'https://api.spotify.com/v1/artists/4vpDg7Y7fU982Ds30zawDA',
#   'id': '4vpDg7Y7fU982Ds30zawDA',
#   'images': [{'height': 743,
#     'url': 'https://i.scdn.co/image/750c386b0ca07258347328b68e171bfcc1addead',
#     'width': 1000},
#    {'height': 475,
#     'url': 'https://i.scdn.co/image/aa48eb0cb57a5f3e2b98dbc1e7acbe4939e129d6',
#     'width': 639},
#    {'height': 149,
#     'url': 'https://i.scdn.co/image/51a692d45507043f7621fae278365b3eb31aa44d',
#     'width': 200},
#    {'height': 48,
#     'url': 'https://i.scdn.co/image/bf4dccd4b2889cf7fdd15d034cda345a2e8386f2',
#     'width': 64}],
#   'name': 'The Band',
#   'popularity': 65,
#   'type': 'artist',
#   'uri': 'spotify:artist:4vpDg7Y7fU982Ds30zawDA'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/08GQAI4eElDnROBrJRGE0X'},
#   'followers': {'href': None, 'total': 7181550},
#   'genres': ['album rock',
#    'classic rock',
#    'mellow gold',
#    'rock',
#    'soft rock',
#    'yacht rock'],
#   'href': 'https://api.spotify.com/v1/artists/08GQAI4eElDnROBrJRGE0X',
#   'id': '08GQAI4eElDnROBrJRGE0X',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb249d55f2d68a44637905c57e',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174249d55f2d68a44637905c57e',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178249d55f2d68a44637905c57e',
#     'width': 160}],
#   'name': 'Fleetwood Mac',
#   'popularity': 82,
#   'type': 'artist',
#   'uri': 'spotify:artist:08GQAI4eElDnROBrJRGE0X'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/16oZKvXb6WkQlVAjwo2Wbg'},
#   'followers': {'href': None, 'total': 4434389},
#   'genres': ['folk-pop', 'modern rock', 'pop rock', 'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/16oZKvXb6WkQlVAjwo2Wbg',
#   'id': '16oZKvXb6WkQlVAjwo2Wbg',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb60d2331a408c313771d31276',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517460d2331a408c313771d31276',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17860d2331a408c313771d31276',
#     'width': 160}],
#   'name': 'The Lumineers',
#   'popularity': 78,
#   'type': 'artist',
#   'uri': 'spotify:artist:16oZKvXb6WkQlVAjwo2Wbg'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/16oZKvXb6WkQlVAjwo2Wbg'},
#   'followers': {'href': None, 'total': 4434389},
#   'genres': ['folk-pop', 'modern rock', 'pop rock', 'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/16oZKvXb6WkQlVAjwo2Wbg',
#   'id': '16oZKvXb6WkQlVAjwo2Wbg',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb60d2331a408c313771d31276',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517460d2331a408c313771d31276',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17860d2331a408c313771d31276',
#     'width': 160}],
#   'name': 'The Lumineers',
#   'popularity': 78,
#   'type': 'artist',
#   'uri': 'spotify:artist:16oZKvXb6WkQlVAjwo2Wbg'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/16oZKvXb6WkQlVAjwo2Wbg'},
#   'followers': {'href': None, 'total': 4434389},
#   'genres': ['folk-pop', 'modern rock', 'pop rock', 'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/16oZKvXb6WkQlVAjwo2Wbg',
#   'id': '16oZKvXb6WkQlVAjwo2Wbg',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb60d2331a408c313771d31276',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517460d2331a408c313771d31276',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17860d2331a408c313771d31276',
#     'width': 160}],
#   'name': 'The Lumineers',
#   'popularity': 78,
#   'type': 'artist',
#   'uri': 'spotify:artist:16oZKvXb6WkQlVAjwo2Wbg'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#   'followers': {'href': None, 'total': 6445637},
#   'genres': ['alternative rock',
#    'art rock',
#    'melancholia',
#    'oxford indie',
#    'permanent wave',
#    'rock'],
#   'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#   'id': '4Z8W4fKeB5YxbusRsdQVPb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eba03696716c9ee605006047fd',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174a03696716c9ee605006047fd',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178a03696716c9ee605006047fd',
#     'width': 160}],
#   'name': 'Radiohead',
#   'popularity': 79,
#   'type': 'artist',
#   'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4dwdTW1Lfiq0cM8nBAqIIz'},
#   'followers': {'href': None, 'total': 3239460},
#   'genres': ['folk-pop',
#    'metropopolis',
#    'modern alternative rock',
#    'modern rock',
#    'pop rock',
#    'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/4dwdTW1Lfiq0cM8nBAqIIz',
#   'id': '4dwdTW1Lfiq0cM8nBAqIIz',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebce5451b5cc60faf1992e969a',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174ce5451b5cc60faf1992e969a',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178ce5451b5cc60faf1992e969a',
#     'width': 160}],
#   'name': 'Of Monsters and Men',
#   'popularity': 71,
#   'type': 'artist',
#   'uri': 'spotify:artist:4dwdTW1Lfiq0cM8nBAqIIz'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7giUHu5pv6YTZgSkxxCcgh'},
#   'followers': {'href': None, 'total': 968760},
#   'genres': ['double drumming',
#    'indie folk',
#    'indie pop',
#    'la indie',
#    'modern rock',
#    'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/7giUHu5pv6YTZgSkxxCcgh',
#   'id': '7giUHu5pv6YTZgSkxxCcgh',
#   'images': [{'height': 968,
#     'url': 'https://i.scdn.co/image/a463748ab96b61a7b839d1e4328e2d33e9a512c6',
#     'width': 924},
#    {'height': 670,
#     'url': 'https://i.scdn.co/image/5a3fe5db609887e8490d35de806a8c51ba02588a',
#     'width': 640},
#    {'height': 210,
#     'url': 'https://i.scdn.co/image/940a038e44f6f1659066341a08139b7846a5d78b',
#     'width': 200},
#    {'height': 67,
#     'url': 'https://i.scdn.co/image/dfe3fd01b4fd6bf997cc8ae07445761f44829147',
#     'width': 64}],
#   'name': 'Edward Sharpe & The Magnetic Zeros',
#   'popularity': 65,
#   'type': 'artist',
#   'uri': 'spotify:artist:7giUHu5pv6YTZgSkxxCcgh'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7giUHu5pv6YTZgSkxxCcgh'},
#   'followers': {'href': None, 'total': 968760},
#   'genres': ['double drumming',
#    'indie folk',
#    'indie pop',
#    'la indie',
#    'modern rock',
#    'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/7giUHu5pv6YTZgSkxxCcgh',
#   'id': '7giUHu5pv6YTZgSkxxCcgh',
#   'images': [{'height': 968,
#     'url': 'https://i.scdn.co/image/a463748ab96b61a7b839d1e4328e2d33e9a512c6',
#     'width': 924},
#    {'height': 670,
#     'url': 'https://i.scdn.co/image/5a3fe5db609887e8490d35de806a8c51ba02588a',
#     'width': 640},
#    {'height': 210,
#     'url': 'https://i.scdn.co/image/940a038e44f6f1659066341a08139b7846a5d78b',
#     'width': 200},
#    {'height': 67,
#     'url': 'https://i.scdn.co/image/dfe3fd01b4fd6bf997cc8ae07445761f44829147',
#     'width': 64}],
#   'name': 'Edward Sharpe & The Magnetic Zeros',
#   'popularity': 65,
#   'type': 'artist',
#   'uri': 'spotify:artist:7giUHu5pv6YTZgSkxxCcgh'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/56ZTgzPBDge0OvCGgMO3OY'},
#   'followers': {'href': None, 'total': 1282079},
#   'genres': ['baltimore indie', 'dream pop', 'dreamo', 'modern dream pop'],
#   'href': 'https://api.spotify.com/v1/artists/56ZTgzPBDge0OvCGgMO3OY',
#   'id': '56ZTgzPBDge0OvCGgMO3OY',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebe8dd3c329c10467fb3d63e3a',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174e8dd3c329c10467fb3d63e3a',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178e8dd3c329c10467fb3d63e3a',
#     'width': 160}],
#   'name': 'Beach House',
#   'popularity': 73,
#   'type': 'artist',
#   'uri': 'spotify:artist:56ZTgzPBDge0OvCGgMO3OY'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/56ZTgzPBDge0OvCGgMO3OY'},
#   'followers': {'href': None, 'total': 1282079},
#   'genres': ['baltimore indie', 'dream pop', 'dreamo', 'modern dream pop'],
#   'href': 'https://api.spotify.com/v1/artists/56ZTgzPBDge0OvCGgMO3OY',
#   'id': '56ZTgzPBDge0OvCGgMO3OY',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebe8dd3c329c10467fb3d63e3a',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174e8dd3c329c10467fb3d63e3a',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178e8dd3c329c10467fb3d63e3a',
#     'width': 160}],
#   'name': 'Beach House',
#   'popularity': 73,
#   'type': 'artist',
#   'uri': 'spotify:artist:56ZTgzPBDge0OvCGgMO3OY'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/57kIMCLPgkzQlXjblX7XXP'},
#   'followers': {'href': None, 'total': 199045},
#   'genres': ['alternative americana',
#    'chamber pop',
#    'freak folk',
#    'indie folk',
#    'indie pop',
#    'indie rock',
#    'new americana',
#    'stomp and holler',
#    'swedish americana'],
#   'href': 'https://api.spotify.com/v1/artists/57kIMCLPgkzQlXjblX7XXP',
#   'id': '57kIMCLPgkzQlXjblX7XXP',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb0695eb77e4b7e89669d83723',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051740695eb77e4b7e89669d83723',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1780695eb77e4b7e89669d83723',
#     'width': 160}],
#   'name': 'Phosphorescent',
#   'popularity': 54,
#   'type': 'artist',
#   'uri': 'spotify:artist:57kIMCLPgkzQlXjblX7XXP'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/57kIMCLPgkzQlXjblX7XXP'},
#   'followers': {'href': None, 'total': 199045},
#   'genres': ['alternative americana',
#    'chamber pop',
#    'freak folk',
#    'indie folk',
#    'indie pop',
#    'indie rock',
#    'new americana',
#    'stomp and holler',
#    'swedish americana'],
#   'href': 'https://api.spotify.com/v1/artists/57kIMCLPgkzQlXjblX7XXP',
#   'id': '57kIMCLPgkzQlXjblX7XXP',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb0695eb77e4b7e89669d83723',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051740695eb77e4b7e89669d83723',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1780695eb77e4b7e89669d83723',
#     'width': 160}],
#   'name': 'Phosphorescent',
#   'popularity': 54,
#   'type': 'artist',
#   'uri': 'spotify:artist:57kIMCLPgkzQlXjblX7XXP'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2BpAc5eK7Rz5GAwSp9UYXa'},
#   'followers': {'href': None, 'total': 598359},
#   'genres': ['indie folk',
#    'stomp and holler',
#    'swedish americana',
#    'swedish singer-songwriter'],
#   'href': 'https://api.spotify.com/v1/artists/2BpAc5eK7Rz5GAwSp9UYXa',
#   'id': '2BpAc5eK7Rz5GAwSp9UYXa',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebe790a3bccaa22e827475113b',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174e790a3bccaa22e827475113b',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178e790a3bccaa22e827475113b',
#     'width': 160}],
#   'name': 'The Tallest Man On Earth',
#   'popularity': 57,
#   'type': 'artist',
#   'uri': 'spotify:artist:2BpAc5eK7Rz5GAwSp9UYXa'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5EM6xJN2QNk0cL7EEm9HR9'},
#   'followers': {'href': None, 'total': 354654},
#   'genres': ['indie folk', 'jacksonville indie', 'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/5EM6xJN2QNk0cL7EEm9HR9',
#   'id': '5EM6xJN2QNk0cL7EEm9HR9',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebc1deb0268116e18ddb60c670',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174c1deb0268116e18ddb60c670',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178c1deb0268116e18ddb60c670',
#     'width': 160}],
#   'name': 'Radical Face',
#   'popularity': 61,
#   'type': 'artist',
#   'uri': 'spotify:artist:5EM6xJN2QNk0cL7EEm9HR9'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5EM6xJN2QNk0cL7EEm9HR9'},
#   'followers': {'href': None, 'total': 354654},
#   'genres': ['indie folk', 'jacksonville indie', 'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/5EM6xJN2QNk0cL7EEm9HR9',
#   'id': '5EM6xJN2QNk0cL7EEm9HR9',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebc1deb0268116e18ddb60c670',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174c1deb0268116e18ddb60c670',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178c1deb0268116e18ddb60c670',
#     'width': 160}],
#   'name': 'Radical Face',
#   'popularity': 61,
#   'type': 'artist',
#   'uri': 'spotify:artist:5EM6xJN2QNk0cL7EEm9HR9'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#   'followers': {'href': None, 'total': 5150777},
#   'genres': ['australian psych', 'neo-psychedelic'],
#   'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#   'id': '5INjqkS1o8h1imAzPqGZBb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb5a2dadeff50fa5c9ad9365c9',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051745a2dadeff50fa5c9ad9365c9',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1785a2dadeff50fa5c9ad9365c9',
#     'width': 160}],
#   'name': 'Tame Impala',
#   'popularity': 79,
#   'type': 'artist',
#   'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1QAJqy2dA3ihHBFIHRphZj'},
#   'followers': {'href': None, 'total': 2669291},
#   'genres': ['ambient pop', 'dream pop', 'el paso indie', 'shoegaze'],
#   'href': 'https://api.spotify.com/v1/artists/1QAJqy2dA3ihHBFIHRphZj',
#   'id': '1QAJqy2dA3ihHBFIHRphZj',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb184c693111b41bc7f101ce8a',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174184c693111b41bc7f101ce8a',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178184c693111b41bc7f101ce8a',
#     'width': 160}],
#   'name': 'Cigarettes After Sex',
#   'popularity': 75,
#   'type': 'artist',
#   'uri': 'spotify:artist:1QAJqy2dA3ihHBFIHRphZj'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4zKYrXs8iN4AeHmO8ZxNqp'},
#   'followers': {'href': None, 'total': 212252},
#   'genres': ['chillwave', 'dream pop', 'metropopolis'],
#   'href': 'https://api.spotify.com/v1/artists/4zKYrXs8iN4AeHmO8ZxNqp',
#   'id': '4zKYrXs8iN4AeHmO8ZxNqp',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebf30c340b28019bc018b59eea',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174f30c340b28019bc018b59eea',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178f30c340b28019bc018b59eea',
#     'width': 160}],
#   'name': 'Still Corners',
#   'popularity': 54,
#   'type': 'artist',
#   'uri': 'spotify:artist:4zKYrXs8iN4AeHmO8ZxNqp'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1QAJqy2dA3ihHBFIHRphZj'},
#   'followers': {'href': None, 'total': 2669291},
#   'genres': ['ambient pop', 'dream pop', 'el paso indie', 'shoegaze'],
#   'href': 'https://api.spotify.com/v1/artists/1QAJqy2dA3ihHBFIHRphZj',
#   'id': '1QAJqy2dA3ihHBFIHRphZj',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb184c693111b41bc7f101ce8a',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174184c693111b41bc7f101ce8a',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178184c693111b41bc7f101ce8a',
#     'width': 160}],
#   'name': 'Cigarettes After Sex',
#   'popularity': 75,
#   'type': 'artist',
#   'uri': 'spotify:artist:1QAJqy2dA3ihHBFIHRphZj'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0OdUWJ0sBjDrqHygGUXeCF'},
#   'followers': {'href': None, 'total': 893990},
#   'genres': ['indie folk',
#    'indie pop',
#    'indie rock',
#    'modern rock',
#    'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/0OdUWJ0sBjDrqHygGUXeCF',
#   'id': '0OdUWJ0sBjDrqHygGUXeCF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb61547959a3bf5330ffa42ddf',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517461547959a3bf5330ffa42ddf',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17861547959a3bf5330ffa42ddf',
#     'width': 160}],
#   'name': 'Band of Horses',
#   'popularity': 61,
#   'type': 'artist',
#   'uri': 'spotify:artist:0OdUWJ0sBjDrqHygGUXeCF'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Jv5eshHtLycR6R8KQCdc4'},
#   'followers': {'href': None, 'total': 779005},
#   'genres': ['alternative dance',
#    'art pop',
#    'baroque pop',
#    'brooklyn indie',
#    'chillwave',
#    'dream pop',
#    'freak folk',
#    'indie pop',
#    'indie rock',
#    'modern rock',
#    'new weird america',
#    'shimmer pop',
#    'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/2Jv5eshHtLycR6R8KQCdc4',
#   'id': '2Jv5eshHtLycR6R8KQCdc4',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebd83c7123395d4e3e6f46f7e8',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174d83c7123395d4e3e6f46f7e8',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178d83c7123395d4e3e6f46f7e8',
#     'width': 160}],
#   'name': 'Grizzly Bear',
#   'popularity': 60,
#   'type': 'artist',
#   'uri': 'spotify:artist:2Jv5eshHtLycR6R8KQCdc4'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0OdUWJ0sBjDrqHygGUXeCF'},
#   'followers': {'href': None, 'total': 893990},
#   'genres': ['indie folk',
#    'indie pop',
#    'indie rock',
#    'modern rock',
#    'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/0OdUWJ0sBjDrqHygGUXeCF',
#   'id': '0OdUWJ0sBjDrqHygGUXeCF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb61547959a3bf5330ffa42ddf',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517461547959a3bf5330ffa42ddf',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17861547959a3bf5330ffa42ddf',
#     'width': 160}],
#   'name': 'Band of Horses',
#   'popularity': 61,
#   'type': 'artist',
#   'uri': 'spotify:artist:0OdUWJ0sBjDrqHygGUXeCF'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#   'followers': {'href': None, 'total': 473470},
#   'genres': ['alternative rock',
#    'art pop',
#    'dream pop',
#    'indie pop',
#    'nu gaze',
#    'reading indie',
#    'shoegaze'],
#   'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#   'id': '72X6FHxaShda0XeQw3vbeF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb7511ff94be3a6b231e61007b',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051747511ff94be3a6b231e61007b',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1787511ff94be3a6b231e61007b',
#     'width': 160}],
#   'name': 'Slowdive',
#   'popularity': 60,
#   'type': 'artist',
#   'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3kjuyTCjPG1WMFCiyc5IuB'},
#   'followers': {'href': None, 'total': 1983582},
#   'genres': ['alternative dance',
#    'alternative rock',
#    'baroque pop',
#    'canadian indie',
#    'indie rock',
#    'modern rock',
#    'new rave',
#    'permanent wave',
#    'quebec indie',
#    'rock',
#    'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/3kjuyTCjPG1WMFCiyc5IuB',
#   'id': '3kjuyTCjPG1WMFCiyc5IuB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebbeab10cf01c618699c4975dd',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174beab10cf01c618699c4975dd',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178beab10cf01c618699c4975dd',
#     'width': 160}],
#   'name': 'Arcade Fire',
#   'popularity': 67,
#   'type': 'artist',
#   'uri': 'spotify:artist:3kjuyTCjPG1WMFCiyc5IuB'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2cCUtGK9sDU2EoElnk0GNB'},
#   'followers': {'href': None, 'total': 1341600},
#   'genres': ['indie pop', 'indie rock', 'modern rock', 'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/2cCUtGK9sDU2EoElnk0GNB',
#   'id': '2cCUtGK9sDU2EoElnk0GNB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb9bdd753a468500e06a864226',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051749bdd753a468500e06a864226',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1789bdd753a468500e06a864226',
#     'width': 160}],
#   'name': 'The National',
#   'popularity': 67,
#   'type': 'artist',
#   'uri': 'spotify:artist:2cCUtGK9sDU2EoElnk0GNB'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LG4Bs1Gadht7TCrMytQUO'},
#   'followers': {'href': None, 'total': 1066353},
#   'genres': ['albuquerque indie',
#    'alternative rock',
#    'indie folk',
#    'indie pop',
#    'indie rock',
#    'modern rock',
#    'pop rock',
#    'portland indie',
#    'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/4LG4Bs1Gadht7TCrMytQUO',
#   'id': '4LG4Bs1Gadht7TCrMytQUO',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb6c87e9e995eedad42e73dcc4',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051746c87e9e995eedad42e73dcc4',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1786c87e9e995eedad42e73dcc4',
#     'width': 160}],
#   'name': 'The Shins',
#   'popularity': 63,
#   'type': 'artist',
#   'uri': 'spotify:artist:4LG4Bs1Gadht7TCrMytQUO'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2BpAc5eK7Rz5GAwSp9UYXa'},
#   'followers': {'href': None, 'total': 598359},
#   'genres': ['indie folk',
#    'stomp and holler',
#    'swedish americana',
#    'swedish singer-songwriter'],
#   'href': 'https://api.spotify.com/v1/artists/2BpAc5eK7Rz5GAwSp9UYXa',
#   'id': '2BpAc5eK7Rz5GAwSp9UYXa',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebe790a3bccaa22e827475113b',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174e790a3bccaa22e827475113b',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178e790a3bccaa22e827475113b',
#     'width': 160}],
#   'name': 'The Tallest Man On Earth',
#   'popularity': 57,
#   'type': 'artist',
#   'uri': 'spotify:artist:2BpAc5eK7Rz5GAwSp9UYXa'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#   'followers': {'href': None, 'total': 5150777},
#   'genres': ['australian psych', 'neo-psychedelic'],
#   'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#   'id': '5INjqkS1o8h1imAzPqGZBb',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb5a2dadeff50fa5c9ad9365c9',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051745a2dadeff50fa5c9ad9365c9',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1785a2dadeff50fa5c9ad9365c9',
#     'width': 160}],
#   'name': 'Tame Impala',
#   'popularity': 79,
#   'type': 'artist',
#   'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2rBcvLKWCZs9w1qIWv560v'},
#   'followers': {'href': None, 'total': 191498},
#   'genres': ['art pop', 'electronica'],
#   'href': 'https://api.spotify.com/v1/artists/2rBcvLKWCZs9w1qIWv560v',
#   'id': '2rBcvLKWCZs9w1qIWv560v',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb5c6941ccec946b6e52c87362',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051745c6941ccec946b6e52c87362',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1785c6941ccec946b6e52c87362',
#     'width': 160}],
#   'name': 'Charlotte Gainsbourg',
#   'popularity': 48,
#   'type': 'artist',
#   'uri': 'spotify:artist:2rBcvLKWCZs9w1qIWv560v'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'},
#   'followers': {'href': None, 'total': 15472234},
#   'genres': ['album rock',
#    'art rock',
#    'classic rock',
#    'progressive rock',
#    'psychedelic rock',
#    'rock',
#    'symphonic rock'],
#   'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9',
#   'id': '0k17h0D3J5VfsdmQ1iZtE9',
#   'images': [{'height': 977,
#     'url': 'https://i.scdn.co/image/e69f71e2be4b67b82af90fb8e9d805715e0684fa',
#     'width': 1000},
#    {'height': 625,
#     'url': 'https://i.scdn.co/image/d011c95081cd9a329e506abd7ded47535d524a07',
#     'width': 640},
#    {'height': 195,
#     'url': 'https://i.scdn.co/image/f0a39a8a196a87a7236bdcf8a8708f6d5d3547cc',
#     'width': 200},
#    {'height': 63,
#     'url': 'https://i.scdn.co/image/ec1fb7127168dbaa962404031409c5a293b95ec6',
#     'width': 64}],
#   'name': 'Pink Floyd',
#   'popularity': 80,
#   'type': 'artist',
#   'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0WwSkZ7LtFUFjGjMZBMt6T'},
#   'followers': {'href': None, 'total': 5079462},
#   'genres': ['album rock', 'classic rock', 'mellow gold', 'rock'],
#   'href': 'https://api.spotify.com/v1/artists/0WwSkZ7LtFUFjGjMZBMt6T',
#   'id': '0WwSkZ7LtFUFjGjMZBMt6T',
#   'images': [{'height': 1021,
#     'url': 'https://i.scdn.co/image/54a86ecf1de16b17e2ed000a9ca8a1590c9a3b80',
#     'width': 1000},
#    {'height': 653,
#     'url': 'https://i.scdn.co/image/caf04a8a030c70dd697ee0b37562033bbe3cdb4f',
#     'width': 640},
#    {'height': 204,
#     'url': 'https://i.scdn.co/image/7756c61bed0dc7650b188a4c7be984dc4e1d7651',
#     'width': 200},
#    {'height': 65,
#     'url': 'https://i.scdn.co/image/0ba7e13266153e59b9b611cbd43e21aec7f6737c',
#     'width': 64}],
#   'name': 'Dire Straits',
#   'popularity': 76,
#   'type': 'artist',
#   'uri': 'spotify:artist:0WwSkZ7LtFUFjGjMZBMt6T'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/432R46LaYsJZV2Gmc4jUV5'},
#   'followers': {'href': None, 'total': 1737458},
#   'genres': ['alternative rock',
#    'art rock',
#    'madchester',
#    'new wave',
#    'post-punk',
#    'rock',
#    'uk post-punk'],
#   'href': 'https://api.spotify.com/v1/artists/432R46LaYsJZV2Gmc4jUV5',
#   'id': '432R46LaYsJZV2Gmc4jUV5',
#   'images': [{'height': 658,
#     'url': 'https://i.scdn.co/image/5eeddd733170399db794d2c430a8d2cde7ae1425',
#     'width': 1000},
#    {'height': 421,
#     'url': 'https://i.scdn.co/image/d3c6bcb07a5ecddf86e791fa901bf3792fe6e6c7',
#     'width': 640},
#    {'height': 132,
#     'url': 'https://i.scdn.co/image/d384ebd3d3fda0ad219fed6b9014a59e65fbb385',
#     'width': 200},
#    {'height': 42,
#     'url': 'https://i.scdn.co/image/1b5195d5e9b5aac07fb0c801deb1926138222036',
#     'width': 64}],
#   'name': 'Joy Division',
#   'popularity': 65,
#   'type': 'artist',
#   'uri': 'spotify:artist:432R46LaYsJZV2Gmc4jUV5'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/22bE4uQ6baNwSHPVcDxLCe'},
#   'followers': {'href': None, 'total': 10814125},
# ...
#   'id': '7G1GBhoKtEPnP86X2PvEYO',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb136c51c848c26a6cce7f9e56',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174136c51c848c26a6cce7f9e56',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178136c51c848c26a6cce7f9e56',
#     'width': 160}],
#   'name': 'Nina Simone',
#   'popularity': 71,
#   'type': 'artist',
#   'uri': 'spotify:artist:7G1GBhoKtEPnP86X2PvEYO'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5I4eibDkC7gg0hmczTZuND'},
#   'followers': {'href': None, 'total': 271019},
#   'genres': ['dalarna indie', 'swedish garage rock', 'swedish indie rock'],
#   'href': 'https://api.spotify.com/v1/artists/5I4eibDkC7gg0hmczTZuND',
#   'id': '5I4eibDkC7gg0hmczTZuND',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb73428e4db4c578bda516a32c',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517473428e4db4c578bda516a32c',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17873428e4db4c578bda516a32c',
#     'width': 160}],
#   'name': 'Mando Diao',
#   'popularity': 58,
#   'type': 'artist',
#   'uri': 'spotify:artist:5I4eibDkC7gg0hmczTZuND'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#   'followers': {'href': None, 'total': 12698277},
#   'genres': ['garage rock', 'permanent wave', 'rock', 'sheffield indie'],
#   'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#   'id': '7Ln80lUS6He07XvHI8qqHH',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb39f37a34b404169fdca52dc8',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517439f37a34b404169fdca52dc8',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17839f37a34b404169fdca52dc8',
#     'width': 160}],
#   'name': 'Arctic Monkeys',
#   'popularity': 84,
#   'type': 'artist',
#   'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/11wRdbnoYqRddKBrpHt4Ue'},
#   'followers': {'href': None, 'total': 1585235},
#   'genres': ['alternative rock',
#    'britpop',
#    'garage rock',
#    'indie rock',
#    'leicester indie',
#    'modern rock',
#    'rock'],
#   'href': 'https://api.spotify.com/v1/artists/11wRdbnoYqRddKBrpHt4Ue',
#   'id': '11wRdbnoYqRddKBrpHt4Ue',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebb58f3e5f0a9b8afcb1c5c15e',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174b58f3e5f0a9b8afcb1c5c15e',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178b58f3e5f0a9b8afcb1c5c15e',
#     'width': 160}],
#   'name': 'Kasabian',
#   'popularity': 64,
#   'type': 'artist',
#   'uri': 'spotify:artist:11wRdbnoYqRddKBrpHt4Ue'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/11wRdbnoYqRddKBrpHt4Ue'},
#   'followers': {'href': None, 'total': 1585235},
#   'genres': ['alternative rock',
#    'britpop',
#    'garage rock',
#    'indie rock',
#    'leicester indie',
#    'modern rock',
#    'rock'],
#   'href': 'https://api.spotify.com/v1/artists/11wRdbnoYqRddKBrpHt4Ue',
#   'id': '11wRdbnoYqRddKBrpHt4Ue',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebb58f3e5f0a9b8afcb1c5c15e',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174b58f3e5f0a9b8afcb1c5c15e',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178b58f3e5f0a9b8afcb1c5c15e',
#     'width': 160}],
#   'name': 'Kasabian',
#   'popularity': 64,
#   'type': 'artist',
#   'uri': 'spotify:artist:11wRdbnoYqRddKBrpHt4Ue'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#   'followers': {'href': None, 'total': 1504269},
#   'genres': ['alternative rock',
#    'britpop',
#    'modern rock',
#    'permanent wave',
#    'rock'],
#   'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#   'id': '6RZUqkomCmb8zCRqc9eznB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eba52698d28f9517190e752b52',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174a52698d28f9517190e752b52',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178a52698d28f9517190e752b52',
#     'width': 160}],
#   'name': 'Placebo',
#   'popularity': 68,
#   'type': 'artist',
#   'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6UUrUCIZtQeOf8tC0WuzRy'},
#   'followers': {'href': None, 'total': 1085285},
#   'genres': ['compositional ambient',
#    'dream pop',
#    'ethereal wave',
#    'icelandic rock',
#    'melancholia',
#    'nordic post-rock',
#    'post-rock'],
#   'href': 'https://api.spotify.com/v1/artists/6UUrUCIZtQeOf8tC0WuzRy',
#   'id': '6UUrUCIZtQeOf8tC0WuzRy',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb19d0792023e59a8dda1dc716',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517419d0792023e59a8dda1dc716',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17819d0792023e59a8dda1dc716',
#     'width': 160}],
#   'name': 'Sigur Rós',
#   'popularity': 58,
#   'type': 'artist',
#   'uri': 'spotify:artist:6UUrUCIZtQeOf8tC0WuzRy'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6urkHDoIVO1WO8vNIwcJmM'},
#   'followers': {'href': None, 'total': 1515590},
#   'genres': ['african rock',
#    'south african alternative',
#    'south african hip hop'],
#   'href': 'https://api.spotify.com/v1/artists/6urkHDoIVO1WO8vNIwcJmM',
#   'id': '6urkHDoIVO1WO8vNIwcJmM',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb2eac7f5f26448433ef465116',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051742eac7f5f26448433ef465116',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1782eac7f5f26448433ef465116',
#     'width': 160}],
#   'name': 'Die Antwoord',
#   'popularity': 62,
#   'type': 'artist',
#   'uri': 'spotify:artist:6urkHDoIVO1WO8vNIwcJmM'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6urkHDoIVO1WO8vNIwcJmM'},
#   'followers': {'href': None, 'total': 1515590},
#   'genres': ['african rock',
#    'south african alternative',
#    'south african hip hop'],
#   'href': 'https://api.spotify.com/v1/artists/6urkHDoIVO1WO8vNIwcJmM',
#   'id': '6urkHDoIVO1WO8vNIwcJmM',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb2eac7f5f26448433ef465116',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051742eac7f5f26448433ef465116',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1782eac7f5f26448433ef465116',
#     'width': 160}],
#   'name': 'Die Antwoord',
#   'popularity': 62,
#   'type': 'artist',
#   'uri': 'spotify:artist:6urkHDoIVO1WO8vNIwcJmM'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5I4eibDkC7gg0hmczTZuND'},
#   'followers': {'href': None, 'total': 271019},
#   'genres': ['dalarna indie', 'swedish garage rock', 'swedish indie rock'],
#   'href': 'https://api.spotify.com/v1/artists/5I4eibDkC7gg0hmczTZuND',
#   'id': '5I4eibDkC7gg0hmczTZuND',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb73428e4db4c578bda516a32c',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517473428e4db4c578bda516a32c',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17873428e4db4c578bda516a32c',
#     'width': 160}],
#   'name': 'Mando Diao',
#   'popularity': 58,
#   'type': 'artist',
#   'uri': 'spotify:artist:5I4eibDkC7gg0hmczTZuND'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#   'followers': {'href': None, 'total': 6651161},
#   'genres': ['modern rock', 'permanent wave', 'rock'],
#   'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#   'id': '12Chz98pHFMPJEknJQMWvI',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebb506164c3174bb7123a41424',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174b506164c3174bb7123a41424',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178b506164c3174bb7123a41424',
#     'width': 160}],
#   'name': 'Muse',
#   'popularity': 77,
#   'type': 'artist',
#   'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#   'followers': {'href': None, 'total': 7426092},
#   'genres': ['british soul', 'indie r&b', 'neo soul'],
#   'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#   'id': '6Q192DXotxtaysaqNPy5yR',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb2ceb023b10da17590878e88c',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051742ceb023b10da17590878e88c',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1782ceb023b10da17590878e88c',
#     'width': 160}],
#   'name': 'Amy Winehouse',
#   'popularity': 77,
#   'type': 'artist',
#   'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IAZ2xX1Ovh5jxhBWE7wda'},
#   'followers': {'href': None, 'total': 338556},
#   'genres': ['neo mellow', 'pop rock'],
#   'href': 'https://api.spotify.com/v1/artists/2IAZ2xX1Ovh5jxhBWE7wda',
#   'id': '2IAZ2xX1Ovh5jxhBWE7wda',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb39566ca17a6bac6445e93cf0',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517439566ca17a6bac6445e93cf0',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17839566ca17a6bac6445e93cf0',
#     'width': 160}],
#   'name': 'Donavon Frankenreiter',
#   'popularity': 60,
#   'type': 'artist',
#   'uri': 'spotify:artist:2IAZ2xX1Ovh5jxhBWE7wda'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6CQrZZn0g2ZNfIcXbi4pdo'},
#   'followers': {'href': None, 'total': 57884},
#   'genres': ['deep new americana', 'indie folk', 'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/6CQrZZn0g2ZNfIcXbi4pdo',
#   'id': '6CQrZZn0g2ZNfIcXbi4pdo',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb5aa5e66436970acfeacf9b8d',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051745aa5e66436970acfeacf9b8d',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1785aa5e66436970acfeacf9b8d',
#     'width': 160}],
#   'name': 'Mason Jennings',
#   'popularity': 44,
#   'type': 'artist',
#   'uri': 'spotify:artist:6CQrZZn0g2ZNfIcXbi4pdo'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/75EZuo5MHV2572NRpMWotC'},
#   'followers': {'href': None, 'total': 341970},
#   'genres': ['alternative dance', 'new rave'],
#   'href': 'https://api.spotify.com/v1/artists/75EZuo5MHV2572NRpMWotC',
#   'id': '75EZuo5MHV2572NRpMWotC',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb9d13d6f4a3f1f2686703fc6e',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051749d13d6f4a3f1f2686703fc6e',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1789d13d6f4a3f1f2686703fc6e',
#     'width': 160}],
#   'name': 'Crystal Fighters',
#   'popularity': 54,
#   'type': 'artist',
#   'uri': 'spotify:artist:75EZuo5MHV2572NRpMWotC'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Z7gV3uEh1ckIaBzTUCE6R'},
#   'followers': {'href': None, 'total': 141322},
#   'genres': ['indie folk',
#    'indie pop',
#    'indie rock',
#    'melancholia',
#    'omaha indie',
#    'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/2Z7gV3uEh1ckIaBzTUCE6R',
#   'id': '2Z7gV3uEh1ckIaBzTUCE6R',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebdb1521ee291c16725c9042c7',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174db1521ee291c16725c9042c7',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178db1521ee291c16725c9042c7',
#     'width': 160}],
#   'name': 'Conor Oberst',
#   'popularity': 53,
#   'type': 'artist',
#   'uri': 'spotify:artist:2Z7gV3uEh1ckIaBzTUCE6R'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4M5nCE77Qaxayuhp3fVn4V'},
#   'followers': {'href': None, 'total': 977066},
#   'genres': ['indie folk', 'indie pop', 'neo mellow', 'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/4M5nCE77Qaxayuhp3fVn4V',
#   'id': '4M5nCE77Qaxayuhp3fVn4V',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb372f49de83296ace5496e1ac',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174372f49de83296ace5496e1ac',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178372f49de83296ace5496e1ac',
#     'width': 160}],
#   'name': 'Iron & Wine',
#   'popularity': 66,
#   'type': 'artist',
#   'uri': 'spotify:artist:4M5nCE77Qaxayuhp3fVn4V'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/05TeWWFqSVEUurt1lVhh4q'},
#   'followers': {'href': None, 'total': 68129},
#   'genres': ['french indie pop'],
#   'href': 'https://api.spotify.com/v1/artists/05TeWWFqSVEUurt1lVhh4q',
#   'id': '05TeWWFqSVEUurt1lVhh4q',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb3a36c007495c391114552420',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051743a36c007495c391114552420',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1783a36c007495c391114552420',
#     'width': 160}],
#   'name': 'Lou Doillon',
#   'popularity': 47,
#   'type': 'artist',
#   'uri': 'spotify:artist:05TeWWFqSVEUurt1lVhh4q'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/44NX2ffIYHr6D4n7RaZF7A'},
#   'followers': {'href': None, 'total': 2221788},
#   'genres': ['classic rock',
#    'folk',
#    'folk rock',
#    'mellow gold',
#    'rock',
#    'roots rock',
#    'singer-songwriter',
#    'soft rock'],
#   'href': 'https://api.spotify.com/v1/artists/44NX2ffIYHr6D4n7RaZF7A',
#   'id': '44NX2ffIYHr6D4n7RaZF7A',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebb30dfdb5154628feb5e46041',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174b30dfdb5154628feb5e46041',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178b30dfdb5154628feb5e46041',
#     'width': 160}],
#   'name': 'Van Morrison',
#   'popularity': 74,
#   'type': 'artist',
#   'uri': 'spotify:artist:44NX2ffIYHr6D4n7RaZF7A'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/79JJCxCCfJ8HufX6w8q2k4'},
#   'followers': {'href': None, 'total': 154547},
#   'genres': ['alternative country',
#    'chamber pop',
#    'freak folk',
#    'indie folk',
#    'indie pop',
#    'indie rock',
#    'new americana',
#    'stomp and holler'],
#   'href': 'https://api.spotify.com/v1/artists/79JJCxCCfJ8HufX6w8q2k4',
#   'id': '79JJCxCCfJ8HufX6w8q2k4',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb60e6bb4c4d216f1d3df0c1d3',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517460e6bb4c4d216f1d3df0c1d3',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17860e6bb4c4d216f1d3df0c1d3',
#     'width': 160}],
#   'name': 'Damien Jurado',
#   'popularity': 55,
#   'type': 'artist',
#   'uri': 'spotify:artist:79JJCxCCfJ8HufX6w8q2k4'}]

# %%
artist_followers = [] #int 
genre = [] #string
artist_popularity = [] #int

length = int(len(all_100_artists))

for x in range(length):
    #retrieve artists' followers
    artist_followers.append(all_100_artists[x]['followers']['total'])
    
    #retrieve artists' popularity
    artist_popularity.append(all_100_artists[x]['popularity'])
    
    #check whether genre is provided, if not append None
    if all_100_artists[x]['genres'][0] == '':
        genre.append(None)
    else:
        genre.append(all_100_artists[x]['genres'][0])

    
#len(artist_followers), len(genre), len(artist_popularity)
#print(artist_followers, '\n', genre,'\n' ,artist_popularity)
# Out:
# [6445637, 745663, 549069, 6445637, 6445637, 1473368, 1473368, 1752572, 1752572, 737470, 326116, 312308, 562053, 562053, 31951841, 31951841, 32104887, 6630543, 10814125, 10814125, 10814125, 5192909, 5192909, 823890, 7181550, 4434389, 4434389, 4434389, 6445637, 3239460, 968760, 968760, 1282079, 1282079, 199045, 199045, 598359, 354654, 354654, 5150777, 2669291, 212252, 2669291, 893990, 779005, 893990, 473470, 1983582, 1341600, 1066353, 598359, 5150777, 191498, 15472234, 5079462, 1737458, 10814125, 3061747, 3061747, 3061747, 3061747, 893990, 950407, 1137207, 1137207, 1148321, 1281041, 5288343, 1907737, 1907737, 1907737, 1285944, 1750771, 965946, 1388411, 879303, 1956205, 1956205, 14113105, 3267426, 2290600, 271019, 12698277, 1585235, 1585235, 1504269, 1085285, 1515590, 1515590, 271019, 6651161, 7426092, 338556, 57884, 341970, 141322, 977066, 68129, 2221788, 154547]
#  ['alternative rock', 'art pop', 'alternative dance', 'alternative rock', 'alternative rock', 'electronica', 'electronica', 'big beat', 'big beat', 'alternative dance', 'alternative dance', 'french indie pop', 'alternative dance', 'alternative dance', 'permanent wave', 'permanent wave', 'brostep', 'beatlesque', 'british invasion', 'british invasion', 'british invasion', 'acid rock', 'acid rock', 'album rock', 'album rock', 'folk-pop', 'folk-pop', 'folk-pop', 'alternative rock', 'folk-pop', 'double drumming', 'double drumming', 'baltimore indie', 'baltimore indie', 'alternative americana', 'alternative americana', 'indie folk', 'indie folk', 'indie folk', 'australian psych', 'ambient pop', 'chillwave', 'ambient pop', 'indie folk', 'alternative dance', 'indie folk', 'alternative rock', 'alternative dance', 'indie pop', 'albuquerque indie', 'indie folk', 'australian psych', 'art pop', 'album rock', 'album rock', 'alternative rock', 'british invasion', 'eau claire indie', 'eau claire indie', 'eau claire indie', 'eau claire indie', 'indie folk', 'gothenburg indie', 'australian indie folk', 'australian indie folk', 'folk', 'metropopolis', 'album rock', 'british singer-songwriter', 'british singer-songwriter', 'british singer-songwriter', 'acoustic rock', 'baroque pop', 'acoustic pop', 'baroque pop', 'albuquerque indie', 'french shoegaze', 'french shoegaze', 'art pop', 'indietronica', 'jazz blues', 'dalarna indie', 'garage rock', 'alternative rock', 'alternative rock', 'alternative rock', 'compositional ambient', 'african rock', 'african rock', 'dalarna indie', 'modern rock', 'british soul', 'neo mellow', 'deep new americana', 'alternative dance', 'indie folk', 'indie folk', 'french indie pop', 'classic rock', 'alternative country']
#  [79, 61, 62, 79, 79, 62, 62, 66, 66, 61, 52, 52, 57, 57, 89, 89, 86, 78, 81, 81, 81, 73, 73, 65, 82, 78, 78, 78, 79, 71, 65, 65, 73, 73, 54, 54, 57, 61, 61, 79, 75, 54, 75, 61, 60, 61, 60, 67, 67, 63, 57, 79, 48, 80, 76, 65, 81, 77, 77, 77, 77, 61, 68, 68, 68, 67, 68, 74, 69, 69, 69, 66, 69, 63, 72, 59, 71, 71, 85, 75, 71, 58, 84, 64, 64, 68, 58, 62, 62, 58, 77, 77, 60, 44, 54, 53, 66, 47, 74, 55]

# %% [markdown]
# The following cells check whether your code is correct. Please **don't write any code here**. Just leave them as they are.

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %% [markdown]
# In addition to the above, there's also additional information we can retrieve about each artist. For this purpose, let's first retrieve the list of distinct artists in our playlist.
#
# <div class="alert alert-info"><b>Exercise 7 </b>Write the code to identify the list of unique artist ids that correspond to the different tracks in your chosen playlist. Store these data in a list called <i>unique_artist_id</i>.<br><i>[1 points]</i></div>

# %%
# YOUR CODE HERE
#turn artist_ids into a set and then again into a list to remove all duplicates
unique_artist_id = list(set(artist_ids))

#test
#print(unique_artist_id)
#len(unique_artist_id)

# %% [markdown]
# The following cells check whether your code is correct. Please **don't write any code here**. Just leave them as they are.

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %% [markdown]
# We are now interested in retrieving catalog information about each artist’s top tracks. This information is provided by Spotify's API on a country basis. Here, we will retrieve the information corresponding to Spain, whose *ISO 3166-1 alpha-2* code is **ES**. The information we are looking for is store dun der to ```top-tracks``` endpoint for ```artists```. Requests to this location retrieve the 10 most famous tracks for a given artist id.
#
# <div class="alert alert-info"><b>Exercise 8 </b>Write the code to retrieve the 10 top tracks for each of the unique artists in your chosen playlist. Store these data in a dictionary called <i>top_tracks</i>. The keys of this dictionary should correspond to the unique artist ids stored in the list <i>unique_artist_id</i>. The values of this dictionary should include the names of the 10 most popular songs in a list.<br><i>[1 points]</i></div>

# %%
# YOUR CODE HERE
url_temp = 'https://api.spotify.com/v1/artists/' # add {id}
endpoint_top_tracks = '/top-tracks'

response_all_artists = {}

for each_id in unique_artist_id:
    url_top_tracks = url_temp + each_id + endpoint_top_tracks
    params = {'id' : each_id, 'market' : 'ES'}
    response_all_artists[each_id] = requests.get(url_top_tracks, params = params, headers = headers).json()
    
#response_all_artists

# %%
top_tracks = {}
all_top_tracks = []
all_tracks = []

for key, value in response_all_artists.items():
    all_tracks.append(value['tracks'])

for each_id in range(len(all_tracks)):
    for song in all_tracks[each_id]:
        all_top_tracks.append(song['name'])
          
i = 0
for element in unique_artist_id:
    top_tracks[element] = all_top_tracks[i:i+10]
    i +=10

# %% [markdown]
# The following cells check whether your code is correct. Please **don't write any code here**. Just leave them as they are.

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %% [markdown]
# We can now use this information to identify those songs in your chosen playlist that correspond to each artist's top tracks.
#
# <div class="alert alert-info"><b>Exercise 9 </b>Write the code to learn whether the different tracks in your chosen playlist are included among the corresponding artist's top tracks. Store the results in a list called <i>is_top</i>. This list should include the entry 'yes' whenever the considered track is among the top tracks for that artist and not otherwise. You code should only look for exact matches.<br><i>[1 points]</i> </div>

# %%
# YOUR CODE HERE
#is_top = []
song_list = []
is_top = []

for each_id, top_10_songs in top_tracks.items():
    for each_song in top_10_songs:
        #put all songs in a list, regardless of the artist
        song_list.append(each_song)

#check whether each song in title is present in song_list        
for song in title:
    if song in song_list:
        is_top.append('yes')
    else: 
        is_top.append('no')

# %% [markdown]
# The following cells check whether your code is correct. Please **don't write any code here**. Just leave them as they are.

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %% [markdown]
# ## Saving the data
#
# The final step is to save the data you have collected to a csv file in order to be able to load it into your BigML account. You can do so by first saving the data to a pandas DataFrame and then exporting it to a csv file of your choosing, in the same directoy where your notebook is located.
#
# Run the following cell to save your DataFrame to a .csv file called 'spotify.csv'.
#
# In what follows, you are going to store all the data you just retrieved in a convenient form.
#
# <div class="alert alert-info"><b>Exercise 10 </b>Write the code to save the data about the title, the name of the album, the name of the artist, the duration, the track number, the release date, the popularity, the id, the number of available markets, the danceability, the energy, the loudness, the mode, the speechiness, the acousticness, the instrumentalness, the liveness, the valence and the tempo for all the tracks included in your chosen playlist, as well as the data about the total number of followers, the first listed genre, the popularity for the artists and whether the tracks are include in the top 10 in a dataframe called <i>df</i> and save this DataFrame to a .csv file called 'spotify.csv'. When creating the dataframe make sure the column names are <b>exactly</b> the same as those of the lists you ccreated in previous exercises to store the different values.<br><i>[0.5 points]</i></div>

# %%
# YOUR CODE HERE
import pandas as pd

dict_data = {'title':title, 'album':album, 'artist':artist, 'duration':duration, 'track_number':track_number, 
             'release_date':release_date, 'track_popularity':track_popularity, 'track_id':track_id, 'n_available_markets':n_available_markets, 
             'danceability':danceability, 'energy':energy, 'loudness':loudness, 'mode':mode, 'speechiness':speechiness, 
             'acousticness':acousticness, 'instrumentalness':instrumentalness, 'liveness':liveness, 'valence':valence, 
             'tempo':tempo, 'artist_followers':artist_followers, 'genre':genre, 'artist_popularity':artist_popularity, 'is_top':is_top}

#create pandas dataframe with all necessary variables
df = pd.DataFrame(dict_data)

#store dataframe in a .csv file (spotify.csv)
df.to_csv('spotify.csv')

# %% [markdown]
# The following cells check whether your code is correct. Please **don't write any code here**. Just leave them as they are.

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %%
# LEAVE BLANK

# %% [markdown]
# ## Bonus exercise
#
# In what follows, you are going to extract certain information from the dataframe you created.
#
# <div class="alert alert-danger"><b>Bonus 1 </b>Write the code to find the most popular song in your playlist. If several songs have the same popularity, choose the one for which the artist has the most followers. Save the name of the song to a new variable called <i>most_popular</i>. This variable should <b>only</b> contain the name of the most popular song in string form.<br><i>[1 points]</div>

# %%
# YOUR CODE HERE
most_popular = ''
most_followers = 0

#find max value of popularity column
max_value = df['track_popularity'].max()
#select rows in which track_popularity equals the max_value found
most_pop_rows = df.loc[df['track_popularity'] == max_value]

#check whether most_pop_rows has more than 1 row
if len(most_pop_rows.index) == 1:
    #store in most_popular the title of the song in the only row 
    most_popular = most_pop_rows.iloc[0]['title']
elif len(most_pop_rows.index) > 1:
    #if most_pop_rows has more than 1 row, find the max value of artist_followers
    most_followers = most_pop_rows['artist_followers'].max()
    #retrieve the row of the song of the artist with the highest number of followers
    most_followers_row = most_pop_rows.loc[most_pop_rows['artist_followers'] == most_followers]
    #store in most_popular the title of the song of the most popular artist
    most_popular = most_followers_row.iloc[0]['title']
    
#print(most_popular)

# %% [markdown]
# The following cells check whether your code is correct. Please **don't write any code here**. Just leave them as they are.

# %%
# LEAVE BLANK
